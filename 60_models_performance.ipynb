# %% [markdown]
# # 60. Models - Performance
# ## Contents
# - Prerequisites
# - Performance
# ---------------------------------------------------------
# ## Prerequisites

# %%
import time
import os
import pandas as pd
import numpy as np
from tqdm import tqdm
import seaborn as sns
import matplotlib.pyplot as plt
import joblib
import warnings
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)
file_path = 'data/'
parties = np.load('00_parties.npy')

# %% [markdown]
# ------------------------------------------------
# <br>
# <br>
# <br>
#
#
# ## Performance

# %%
dur = time.time()
results = pd.DataFrame(columns=['Party', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Confusion Matrix'])
# -------------------------------------------------------------------------------------~----------------------------------------

for party in tqdm(parties, desc='Party loop'):                                         # for each party
    print(party)                                                                       # print party
    print("-----------------------------------------------------------------------")
    
    # load model
    # -------------------------------------------------------------------------
    model_url = file_path + f"50_models/{party}.pkl"                                   # define model url
    loaded_model = joblib.load(model_url)                                              # load model
    
    # load test data
    # -------------------------------------------------------------------------
    X_test_url = file_path + f"40_models_imbalanced/" + f"{party}_X_test.csv"          # define X_test url
    y_test_url = file_path + f"40_models_imbalanced/" + f"{party}_y_test.csv"          # define y_test url
    X_test = pd.read_csv(X_test_url)                                                   # read X_test
    X_test = X_test.drop(columns=['source', 'text','stemming_id','document_id'])       # redefine X_test, drop columns
    y_test = pd.read_csv(y_test_url)                                                   # read y_test
    
    # predict on test data
    # -------------------------------------------------------------------------
    y_pred = loaded_model.predict(X_test)                                              # predict y_test using X_test and model
    
    # calculate performance metrics
    # -------------------------------------------------------------------------
    accuracy = accuracy_score(y_test, y_pred)                                          # calculate performance metrics accuracy
    precision = precision_score(y_test, y_pred)                                        # calculate performance metrics precision
    recall = recall_score(y_test, y_pred)                                              # calculate performance metrics recall
    f1 = f1_score(y_test, y_pred)                                                      # calculate performance metrics f1
    cm = confusion_matrix(y_test, y_pred)                                              # calculate performance metrics cm
        
    # store results
    # -------------------------------------------------------------------------
    result = pd.DataFrame({
        'Party': [party],
        'Accuracy': [accuracy],
        'Precision': [precision],
        'Recall': [recall],
        'F1 Score': [f1],
        'Confusion Matrix': [cm]})
    results = pd.concat([results, result], ignore_index=True)                          # define result
    display(result)                                                                    # display result
    
    # display results
    # -------------------------------------------------------------------------
    sns.set(font_scale=1.2)                                                            # plot scale
    sns.set_style("whitegrid")                                                         # plot style
    fig, ax = plt.subplots(figsize=(8, 6))                                             # plot subplots
    sns.heatmap(cm, annot=True, fmt="g", cmap="Greys", cbar=False, annot_kws={"size": 14}, ax=ax)
    sns.despine()                                                                      # plot despine
    ax.set_xlabel("Predicted Label")                                                   # plot xlabel
    ax.set_ylabel("True Label")                                                        # plot ylabel
    ax.set_title(f"{party} Confusion Matrix")                                          # plot title
    plt.show()                                                                         # plot show
    print("\n\n\n")                                                                    # print spacers
    
# -------------------------------------------------------------------------------------~----------------------------------------
display(results)                                                                       # display results
print('\n---------------------------------------------------------------------------------------------------------------------')
print(f"Code duration: {round((time.time()  - dur),3)} seconds")
# Out:
# Party loop:   0%|          | 0/18 [00:00<?, ?it/s]
# 50PLUS
# -----------------------------------------------------------------------
#     Party  Accuracy  Precision    Recall  F1 Score          Confusion Matrix
# 0  50PLUS   0.80515    0.81182  0.980896  0.888385  [[120, 726], [61, 3132]]
# Party loop:   6%|▌         | 1/18 [00:01<00:17,  1.01s/it]
# CDA
# -----------------------------------------------------------------------
#   Party  Accuracy  Precision    Recall  F1 Score            Confusion Matrix
# 0   CDA  0.696705   0.681338  0.745665  0.712052  [[1328, 724], [528, 1548]]
# Party loop:  11%|█         | 2/18 [00:01<00:11,  1.37it/s]
# CU
# -----------------------------------------------------------------------
#   Party  Accuracy  Precision    Recall  F1 Score            Confusion Matrix
# 0    CU  0.700946   0.693605  0.796396  0.741455  [[1122, 781], [452, 1768]]
# Party loop:  17%|█▋        | 3/18 [00:02<00:11,  1.30it/s]
# D66
# -----------------------------------------------------------------------
#   Party  Accuracy  Precision    Recall  F1 Score            Confusion Matrix
# 0   D66  0.691711   0.683868  0.773082  0.725744  [[1171, 778], [494, 1683]]
# Party loop:  22%|██▏       | 4/18 [00:03<00:11,  1.25it/s]
# DENK
# -----------------------------------------------------------------------
#   Party  Accuracy  Precision    Recall  F1 Score          Confusion Matrix
# 0  DENK  0.841786   0.846057  0.987938  0.911509  [[111, 611], [41, 3358]]
# Party loop:  28%|██▊       | 5/18 [00:04<00:10,  1.20it/s]
# FVD
# -----------------------------------------------------------------------
#   Party  Accuracy  Precision    Recall  F1 Score           Confusion Matrix
# 0   FVD  0.706055   0.709211  0.872521  0.782435  [[724, 884], [315, 2156]]
# Party loop:  33%|███▎      | 6/18 [00:06<00:14,  1.22s/it]
# GLPvdA
# -----------------------------------------------------------------------
#     Party  Accuracy  Precision    Recall  F1 Score          Confusion Matrix
# 0  GLPvdA  0.824625   0.829014  0.984314  0.900014  [[146, 673], [52, 3263]]
# Party loop:  39%|███▉      | 7/18 [00:07<00:13,  1.20s/it]
# PVV
# -----------------------------------------------------------------------
#   Party  Accuracy  Precision    Recall  F1 Score           Confusion Matrix
# 0   PVV  0.716606    0.71844  0.886435  0.793645  [[708, 881], [288, 2248]]
# Party loop:  44%|████▍     | 8/18 [00:09<00:13,  1.39s/it]
# PvdD
# -----------------------------------------------------------------------
#   Party  Accuracy  Precision    Recall  F1 Score          Confusion Matrix
# 0  PvdD  0.799418   0.802668  0.986696  0.885219  [[107, 784], [43, 3189]]
# Party loop:  50%|█████     | 9/18 [00:10<00:13,  1.52s/it]
# SGP
# -----------------------------------------------------------------------
#   Party  Accuracy  Precision    Recall  F1 Score            Confusion Matrix
# 0   SGP  0.684988   0.693384  0.905251  0.785278  [[450, 1052], [249, 2379]]
# Party loop:  56%|█████▌    | 10/18 [00:12<00:13,  1.64s/it]
# SP
# -----------------------------------------------------------------------
#   Party  Accuracy  Precision    Recall  F1 Score         Confusion Matrix
# 0    SP  0.819811   0.823544  0.991384  0.899703  [[48, 715], [29, 3337]]
# Party loop:  61%|██████    | 11/18 [00:13<00:10,  1.51s/it]
# VVD
# -----------------------------------------------------------------------
#   Party  Accuracy  Precision    Recall  F1 Score            Confusion Matrix
# 0   VVD  0.686683   0.669545  0.617631  0.642541  [[1673, 574], [720, 1163]]
# Party loop:  67%|██████▋   | 12/18 [00:14<00:08,  1.36s/it]
# BVNL
# -----------------------------------------------------------------------
#   Party  Accuracy  Precision    Recall  F1 Score           Confusion Matrix
# 0  BVNL  0.704747   0.703583  0.921951    0.7981  [[314, 637], [128, 1512]]
# Party loop:  72%|███████▏  | 13/18 [00:16<00:06,  1.29s/it]
# BBB
# -----------------------------------------------------------------------
#   Party  Accuracy  Precision    Recall  F1 Score         Confusion Matrix
# 0   BBB  0.834725   0.840159  0.989283  0.908643  [[23, 281], [16, 1477]]
# Party loop:  78%|███████▊  | 14/18 [00:16<00:04,  1.09s/it]
# BIJ1
# -----------------------------------------------------------------------
#   Party  Accuracy  Precision    Recall  F1 Score         Confusion Matrix
# 0  BIJ1  0.791613   0.790587  0.986383  0.877698  [[68, 307], [16, 1159]]
# Party loop:  83%|████████▎ | 15/18 [00:17<00:02,  1.06it/s]
# JA21
# -----------------------------------------------------------------------
#   Party  Accuracy  Precision    Recall  F1 Score          Confusion Matrix
# 0  JA21  0.699505   0.701923  0.931122  0.800439  [[176, 465], [81, 1095]]
# Party loop:  89%|████████▉ | 16/18 [00:17<00:01,  1.18it/s]
# NSC
# -----------------------------------------------------------------------
#   Party  Accuracy  Precision    Recall  F1 Score         Confusion Matrix
# 0   NSC  0.771893   0.777037  0.979458  0.866584  [[44, 301], [22, 1049]]
# Party loop:  94%|█████████▍| 17/18 [00:18<00:00,  1.35it/s]
# Volt
# -----------------------------------------------------------------------
#   Party  Accuracy  Precision    Recall  F1 Score          Confusion Matrix
# 0  Volt  0.802089   0.804309  0.976035   0.88189  [[115, 327], [33, 1344]]
# Party loop: 100%|██████████| 18/18 [00:19<00:00,  1.06s/it]
#      Party  Accuracy  Precision    Recall  F1 Score  \
# 0   50PLUS  0.805150   0.811820  0.980896  0.888385
# 1      CDA  0.696705   0.681338  0.745665  0.712052
# 2       CU  0.700946   0.693605  0.796396  0.741455
# 3      D66  0.691711   0.683868  0.773082  0.725744
# 4     DENK  0.841786   0.846057  0.987938  0.911509
# 5      FVD  0.706055   0.709211  0.872521  0.782435
# 6   GLPvdA  0.824625   0.829014  0.984314  0.900014
# 7      PVV  0.716606   0.718440  0.886435  0.793645
# 8     PvdD  0.799418   0.802668  0.986696  0.885219
# 9      SGP  0.684988   0.693384  0.905251  0.785278
# 10      SP  0.819811   0.823544  0.991384  0.899703
# 11     VVD  0.686683   0.669545  0.617631  0.642541
# 12    BVNL  0.704747   0.703583  0.921951  0.798100
# 13     BBB  0.834725   0.840159  0.989283  0.908643
# 14    BIJ1  0.791613   0.790587  0.986383  0.877698
# 15    JA21  0.699505   0.701923  0.931122  0.800439
# 16     NSC  0.771893   0.777037  0.979458  0.866584
# 17    Volt  0.802089   0.804309  0.976035  0.881890
#
#               Confusion Matrix
# 0     [[120, 726], [61, 3132]]
# 1   [[1328, 724], [528, 1548]]
# 2   [[1122, 781], [452, 1768]]
# 3   [[1171, 778], [494, 1683]]
# 4     [[111, 611], [41, 3358]]
# 5    [[724, 884], [315, 2156]]
# 6     [[146, 673], [52, 3263]]
# 7    [[708, 881], [288, 2248]]
# 8     [[107, 784], [43, 3189]]
# 9   [[450, 1052], [249, 2379]]
# 10     [[48, 715], [29, 3337]]
# 11  [[1673, 574], [720, 1163]]
# 12   [[314, 637], [128, 1512]]
# 13     [[23, 281], [16, 1477]]
# 14     [[68, 307], [16, 1159]]
# 15    [[176, 465], [81, 1095]]
# 16     [[44, 301], [22, 1049]]
# 17    [[115, 327], [33, 1344]]
# ---------------------------------------------------------------------------------------------------------------------
# Code duration: 19.057 seconds

# %%
# Normalize the confusion matrix averages to represent ratios
average_metrics = results[['Accuracy', 'Precision', 'Recall', 'F1 Score']].mean().to_dict()
average_cm = np.mean(results['Confusion Matrix'].tolist(), axis=0)

# Normalize the confusion matrix ratio based on the total sum
total_sum = np.sum(average_cm)
average_cm_ratio = average_cm / total_sum

# Round the values in the confusion matrix ratio
average_cm_ratio_rounded = np.round(average_cm_ratio, 3)

# Create a DataFrame for averages
average_df = pd.DataFrame({
    'Party': ['Average'],
    'Accuracy': [average_metrics['Accuracy']],
    'Precision': [average_metrics['Precision']],
    'Recall': [average_metrics['Recall']],
    'F1 Score': [average_metrics['F1 Score']],
    'Confusion Matrix Ratio': [average_cm_ratio_rounded]
})

# Display the average DataFrame
display(average_df)
# Out:
#      Party  Accuracy  Precision    Recall  F1 Score  \
# 0  Average  0.754392    0.75445  0.906247  0.822296
#
#           Confusion Matrix Ratio
# 0  [[0.14, 0.19], [0.059, 0.61]]

# %%
sns.set(font_scale=1.2)
sns.set_style("whitegrid") 
fig, ax = plt.subplots(figsize=(8, 6))

# Explicitly set fmt='.2%'
sns.heatmap(average_cm_ratio, annot=True, fmt=".4%", cmap="Greys", cbar=False, annot_kws={"size": 14}, ax=ax)

sns.despine()
ax.set_xlabel("Predicted Label")
ax.set_ylabel("True Label")
ax.set_title("Average Confusion Matrix")
plt.show()
