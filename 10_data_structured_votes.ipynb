# %% [markdown]
# # 10. Data structured (votes)
# ## Contents
# - Prerequisites
# - Data retrieval
#     - API test
#     - API processing
#     - API url
#     - API extraction
# - Data processing
# ------------------------------------------------
# ## Prerequisites

# %%
import requests
import time
from datetime import datetime
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
file_path = 'data/'
api_path  = 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/'

# %% [markdown]
# ------------------------------------------------
# <br>
# <br>
# <br>
#
# ## Data retrieval
# ### API test

# %%
dur = time.time()
# -------------------------------------------------------------------------------------~----------------------------------------

api_url = api_path                                                                     # define API url
response = requests.get(api_url)                                                       # request response

if response.status_code == 200:                                                        # if reponse is 200
    print("API request successfull")                                                   # print succes
else:                                                                                  # if not
    print(f"API request failed, code: {response.status_code}")                         # print failure + code

# -------------------------------------------------------------------------------------~----------------------------------------
print()
print('-----------------------------------------------------------------------------------------------------------------------')
print(f"Code duration: {round((time.time()  - dur),3)} seconds")
# Out:
# API request successfull
#
# -----------------------------------------------------------------------------------------------------------------------
# Code duration: 0.113 seconds

# %% [markdown]
# ### API processing

# %%
# select columns
# -------------------------------------------------------------------------------------~----------------------------------------
stemming_columns = "Id, Soort"
fractie_columns = "Id, Afkorting"
besluit_columns = "Id"
zaak_columns = "Id, GestartOp"
document_columns = "Id,Titel,Onderwerp"

# filter columns
# -------------------------------------------------------------------------------------~----------------------------------------
stemming_filters = "Verwijderd eq false and Soort ne 'Niet deelgenomen' and Vergissing eq false" 
fractie_filters = "Verwijderd eq false" 
besluit_filters = "Verwijderd eq false" 
zaak_filters = "Verwijderd eq false and Soort eq 'Motie' and Afgedaan ne false and Year(GestartOp) ge 2017" 
document_filters = "Verwijderd eq false and ContentType eq 'application/pdf' and Soort eq 'Motie' or Soort eq 'Motie (gewijzigd/nader)'"

# %% [markdown]
# ### API url

# %%
# base URL + main table Stemming
# -------------------------------------------------------------------------------------~----------------------------------------
api_url = api_path + "Stemming"                                                        # api_path + main table Stemming
api_url += "?$select=" + stemming_columns                                              ## select Stemming columns
api_url += "&$filter=" + stemming_filters                                              ## filter Stemming

# 1st level expand into Fractie and Besluit
# -------------------------------------------------------------------------------------~----------------------------------------
api_url += "&$expand="                                                                 # expand 1st level
api_url += "Fractie"                                                                     # join Fractie             
api_url += "($select=" + fractie_columns                                                 ## select Fractie columns
api_url += ";$filter=" + fractie_filters                                                 ## filter Fractie
api_url += "),Besluit"                                                                   # join Besluit
api_url += "($select=" + besluit_columns                                                 ## select Besluit columns
api_url += ";$filter=" + besluit_filters                                                 ## filter Besluit

# 2nd level expand into Zaak
# -------------------------------------------------------------------------------------~----------------------------------------
api_url += ";$expand="                                                                      # expand 2nd level
api_url += "Zaak"                                                                           # join Zaak
api_url += "($select=" + zaak_columns                                                       ## select Zaak columns
api_url += ";$filter=" + zaak_filters                                                       ## filter Zaak

# 3rd level expand into Document
# -------------------------------------------------------------------------------------~----------------------------------------
api_url += ";$expand="                                                                         # expand 3rd level
api_url += "Document"                                                                          # join Document
api_url += "($select=" + document_columns                                                      ## select Document columns
api_url += ";$filter=" + document_filters + ")))"                                              ## filter Document

# %% [markdown]
# ### API extraction

# %%
dur = time.time()
# -------------------------------------------------------------------------------------~----------------------------------------

# 1st level extraction
# -------------------------------------------------------------------------------------~----------------------------------------
page = 1                                                                               # Define page one
while True:                                                                            # Start page loop
    page_dur = time.time()                                                             # Define page duration 
    r = requests.get(api_url, params={'$top': 250, '$skip': (page - 1) * 250})         # Request api data
    json_data = r.json()['value']                                                      # Transform json data
    json_normalized = pd.json_normalize(json_data)                                     # Normalize json data
    if json_normalized.empty: break                                                    # Break when empty
    tables = json_normalized                                                           # 1st level
    
# 2nd level extraction
# -------------------------------------------------------------------------------------~----------------------------------------
    tables_exploded = tables.explode("Besluit.Zaak")                                   # Explode nested json
    stemming = tables_exploded.drop("Besluit.Zaak", axis=1)                            # Drop nested json column
    zaak = pd.json_normalize(tables_exploded["Besluit.Zaak"])                          # Normalize nested json
    
    stemming = stemming.add_prefix('stemming_')                                        # Add prefix, prevent duplicates
    zaak = zaak.add_prefix('zaak_')                                                    # Add prefix, prevent duplicates
    stemming['stemming_index'] = range(len(stemming))                                  # Define new index
    zaak['zaak_index'] = range(len(zaak))                                              # Define new index
    stemming.reset_index(drop=True, inplace=True)                                      # Drop old index
    zaak.reset_index(drop=True, inplace=True)                                          # Drop old index
    stemming.sort_values(by= ('stemming_index') , inplace=True)                        # Sort by new index
    zaak.sort_values(by= ('zaak_index') , inplace=True)                                # Sort by new index

    tables = pd.concat([stemming, zaak], axis=1)                                       # Concat using sorted index
    tables.sort_values(by= ('stemming_index'), inplace=True)                           # Sort result
    tables.drop([ ('stemming_index'), ('zaak_index')], axis=1, inplace=True)           # Drop new indexes

# 3rd level extraction
# -------------------------------------------------------------------------------------~----------------------------------------
    tables_exploded = tables.explode("zaak_Document")                                  # Explode nested json
    stemmingzaak = tables_exploded.drop("zaak_Document", axis=1)                       # Drop nested json column
    document = pd.json_normalize(tables_exploded["zaak_Document"])                     # Normalize nested json

    stemmingzaak = stemmingzaak.add_prefix('stemmingzaak_')                            # Add prefix, prevent duplicates
    document = document.add_prefix('document_')                                        # Add prefix, prevent duplicates
    stemmingzaak['stemmingzaak_index'] = range(len(stemmingzaak))                      # Define new index
    document['document_index'] = range(len(document))                                  # Define new index
    stemmingzaak.reset_index(drop=True, inplace=True)                                  # Drop old index
    document.reset_index(drop=True, inplace=True)                                      # Drop old index
    stemmingzaak.sort_values(by= ('stemmingzaak_index') , inplace=True)                # Sort by new index
    document.sort_values(by= ('document_index') , inplace=True)                        # Sort by new index

    tables = pd.concat([stemmingzaak, document], axis=1)                               # Concat, using sorted index
    tables.sort_values(by= ('stemmingzaak_index'), inplace=True)                       # Sort result
    tables.drop([ ('stemmingzaak_index'), ('document_index')], axis=1, inplace=True)   # Drop new indexes
    tables.dropna(subset=['document_Id'], inplace=True)                                # Drop empty rows, due to filters

# data load
# -------------------------------------------------------------------------------------~----------------------------------------
    if page == 1: result = tables                                                      # Define result, first page
    else: result = pd.concat([result,tables], ignore_index=True)                       # Concat pages
    page_dur = round((time.time() - page_dur),2)                                       # Define page duration 
    print(f"Successful extraction (Page {page}) (Time {page_dur})")                    # Print page log
    page += 1                                                                          # Define next page

# -------------------------------------------------------------------------------------~----------------------------------------
file_url  = file_path + '11_data_structured_retrieved.csv'            
result.to_csv(file_url, index=False)    
print('\n---------------------------------------------------------------------------------------------------------------------')
print(f"Code duration: {round((time.time()  - dur),3)} seconds")
# Out:
# Successful extraction (Page 1) (Time 0.17)
# Successful extraction (Page 2) (Time 0.17)
# Successful extraction (Page 3) (Time 0.16)
# Successful extraction (Page 4) (Time 0.18)
# Successful extraction (Page 5) (Time 0.22)
# Successful extraction (Page 6) (Time 0.22)
# Successful extraction (Page 7) (Time 0.22)
# Successful extraction (Page 8) (Time 0.18)
# Successful extraction (Page 9) (Time 0.21)
# Successful extraction (Page 10) (Time 0.18)
# Successful extraction (Page 11) (Time 0.17)
# Successful extraction (Page 12) (Time 0.16)
# Successful extraction (Page 13) (Time 0.18)
# Successful extraction (Page 14) (Time 0.21)
# Successful extraction (Page 15) (Time 0.17)
# Successful extraction (Page 16) (Time 0.17)
# Successful extraction (Page 17) (Time 0.17)
# Successful extraction (Page 18) (Time 0.16)
# Successful extraction (Page 19) (Time 0.18)
# Successful extraction (Page 20) (Time 0.22)
# Successful extraction (Page 21) (Time 0.18)
# Successful extraction (Page 22) (Time 0.18)
# Successful extraction (Page 23) (Time 0.18)
# Successful extraction (Page 24) (Time 0.19)
# Successful extraction (Page 25) (Time 0.19)
# Successful extraction (Page 26) (Time 0.16)
# Successful extraction (Page 27) (Time 0.15)
# Successful extraction (Page 28) (Time 0.22)
# Successful extraction (Page 29) (Time 0.23)
# Successful extraction (Page 30) (Time 0.18)
# Successful extraction (Page 31) (Time 0.21)
# Successful extraction (Page 32) (Time 0.18)
# Successful extraction (Page 33) (Time 0.75)
# Successful extraction (Page 34) (Time 0.16)
# Successful extraction (Page 35) (Time 0.22)
# Successful extraction (Page 36) (Time 0.17)
# Successful extraction (Page 37) (Time 0.2)
# Successful extraction (Page 38) (Time 0.2)
# Successful extraction (Page 39) (Time 0.22)
# Successful extraction (Page 40) (Time 0.2)
# Successful extraction (Page 41) (Time 0.23)
# Successful extraction (Page 42) (Time 0.15)
# Successful extraction (Page 43) (Time 0.19)
# Successful extraction (Page 44) (Time 0.16)
# Successful extraction (Page 45) (Time 0.18)
# Successful extraction (Page 46) (Time 0.23)
# Successful extraction (Page 47) (Time 0.36)
# Successful extraction (Page 48) (Time 0.18)
# Successful extraction (Page 49) (Time 0.14)
# Successful extraction (Page 50) (Time 0.19)
# Successful extraction (Page 51) (Time 0.39)
# Successful extraction (Page 52) (Time 0.25)
# Successful extraction (Page 53) (Time 0.22)
# Successful extraction (Page 54) (Time 0.18)
# Successful extraction (Page 55) (Time 0.24)
# Successful extraction (Page 56) (Time 0.2)
# Successful extraction (Page 57) (Time 0.19)
# Successful extraction (Page 58) (Time 0.69)
# Successful extraction (Page 59) (Time 0.22)
# Successful extraction (Page 60) (Time 0.22)
# Successful extraction (Page 61) (Time 0.19)
# Successful extraction (Page 62) (Time 0.19)
# Successful extraction (Page 63) (Time 0.42)
# Successful extraction (Page 64) (Time 0.25)
# Successful extraction (Page 65) (Time 0.16)
# Successful extraction (Page 66) (Time 0.22)
# Successful extraction (Page 67) (Time 0.15)
# Successful extraction (Page 68) (Time 0.19)
# Successful extraction (Page 69) (Time 0.23)
# Successful extraction (Page 70) (Time 0.23)
# Successful extraction (Page 71) (Time 0.23)
# Successful extraction (Page 72) (Time 0.17)
# Successful extraction (Page 73) (Time 0.35)
# Successful extraction (Page 74) (Time 0.26)
# Successful extraction (Page 75) (Time 0.59)
# Successful extraction (Page 76) (Time 0.19)
# Successful extraction (Page 77) (Time 0.21)
# Successful extraction (Page 78) (Time 0.31)
# Successful extraction (Page 79) (Time 0.16)
# Successful extraction (Page 80) (Time 0.21)
# Successful extraction (Page 81) (Time 0.18)
# Successful extraction (Page 82) (Time 0.2)
# Successful extraction (Page 83) (Time 0.2)
# Successful extraction (Page 84) (Time 0.24)
# Successful extraction (Page 85) (Time 0.18)
# Successful extraction (Page 86) (Time 0.23)
# Successful extraction (Page 87) (Time 0.18)
# Successful extraction (Page 88) (Time 0.22)
# Successful extraction (Page 89) (Time 0.27)
# Successful extraction (Page 90) (Time 0.85)
# Successful extraction (Page 91) (Time 0.2)
# Successful extraction (Page 92) (Time 0.17)
# Successful extraction (Page 93) (Time 0.21)
# Successful extraction (Page 94) (Time 0.19)
# Successful extraction (Page 95) (Time 0.16)
# Successful extraction (Page 96) (Time 0.17)
# Successful extraction (Page 97) (Time 0.18)
# Successful extraction (Page 98) (Time 0.18)
# Successful extraction (Page 99) (Time 0.27)
# Successful extraction (Page 100) (Time 0.18)
# Successful extraction (Page 101) (Time 0.63)
# Successful extraction (Page 102) (Time 0.18)
# Successful extraction (Page 103) (Time 0.18)
# Successful extraction (Page 104) (Time 0.17)
# Successful extraction (Page 105) (Time 0.24)
# Successful extraction (Page 106) (Time 0.17)
# Successful extraction (Page 107) (Time 0.23)
# Successful extraction (Page 108) (Time 0.22)
# Successful extraction (Page 109) (Time 0.19)
# Successful extraction (Page 110) (Time 0.19)
# Successful extraction (Page 111) (Time 0.24)
# Successful extraction (Page 112) (Time 0.17)
# Successful extraction (Page 113) (Time 0.18)
# Successful extraction (Page 114) (Time 0.2)
# Successful extraction (Page 115) (Time 0.31)
# Successful extraction (Page 116) (Time 0.22)
# Successful extraction (Page 117) (Time 0.19)
# Successful extraction (Page 118) (Time 0.15)
# Successful extraction (Page 119) (Time 0.75)
# Successful extraction (Page 120) (Time 0.19)
# Successful extraction (Page 121) (Time 0.23)
# Successful extraction (Page 122) (Time 0.21)
# Successful extraction (Page 123) (Time 0.18)
# Successful extraction (Page 124) (Time 0.18)
# Successful extraction (Page 125) (Time 0.18)
# Successful extraction (Page 126) (Time 0.18)
# Successful extraction (Page 127) (Time 0.29)
# Successful extraction (Page 128) (Time 0.23)
# Successful extraction (Page 129) (Time 0.23)
# Successful extraction (Page 130) (Time 0.18)
# Successful extraction (Page 131) (Time 0.21)
# Successful extraction (Page 132) (Time 0.21)
# Successful extraction (Page 133) (Time 0.22)
# Successful extraction (Page 134) (Time 0.17)
# Successful extraction (Page 135) (Time 0.23)
# Successful extraction (Page 136) (Time 0.17)
# Successful extraction (Page 137) (Time 0.2)
# Successful extraction (Page 138) (Time 0.2)
# Successful extraction (Page 139) (Time 0.2)
# Successful extraction (Page 140) (Time 0.19)
# Successful extraction (Page 141) (Time 0.18)
# Successful extraction (Page 142) (Time 0.18)
# Successful extraction (Page 143) (Time 0.18)
# Successful extraction (Page 144) (Time 0.19)
# Successful extraction (Page 145) (Time 0.23)
# Successful extraction (Page 146) (Time 0.26)
# Successful extraction (Page 147) (Time 0.18)
# Successful extraction (Page 148) (Time 0.41)
# Successful extraction (Page 149) (Time 0.23)
# Successful extraction (Page 150) (Time 0.18)
# Successful extraction (Page 151) (Time 0.23)
# Successful extraction (Page 152) (Time 0.27)
# Successful extraction (Page 153) (Time 0.22)
# Successful extraction (Page 154) (Time 0.21)
# Successful extraction (Page 155) (Time 0.2)
# Successful extraction (Page 156) (Time 0.22)
# Successful extraction (Page 157) (Time 0.2)
# Successful extraction (Page 158) (Time 0.24)
# Successful extraction (Page 159) (Time 0.29)
# Successful extraction (Page 160) (Time 0.26)
# Successful extraction (Page 161) (Time 0.18)
# Successful extraction (Page 162) (Time 0.24)
# Successful extraction (Page 163) (Time 0.22)
# Successful extraction (Page 164) (Time 0.22)
# Successful extraction (Page 165) (Time 0.2)
# Successful extraction (Page 166) (Time 0.21)
# Successful extraction (Page 167) (Time 0.72)
# Successful extraction (Page 168) (Time 0.24)
# Successful extraction (Page 169) (Time 0.23)
# Successful extraction (Page 170) (Time 0.18)
# Successful extraction (Page 171) (Time 0.22)
# Successful extraction (Page 172) (Time 0.22)
# Successful extraction (Page 173) (Time 0.19)
# Successful extraction (Page 174) (Time 0.2)
# Successful extraction (Page 175) (Time 0.2)
# Successful extraction (Page 176) (Time 0.22)
# Successful extraction (Page 177) (Time 0.26)
# Successful extraction (Page 178) (Time 0.24)
# Successful extraction (Page 179) (Time 0.25)
# Successful extraction (Page 180) (Time 0.3)
# Successful extraction (Page 181) (Time 0.22)
# Successful extraction (Page 182) (Time 0.2)
# Successful extraction (Page 183) (Time 0.21)
# Successful extraction (Page 184) (Time 0.22)
# Successful extraction (Page 185) (Time 0.26)
# Successful extraction (Page 186) (Time 0.27)
# Successful extraction (Page 187) (Time 0.33)
# Successful extraction (Page 188) (Time 0.23)
# Successful extraction (Page 189) (Time 0.19)
# Successful extraction (Page 190) (Time 0.21)
# Successful extraction (Page 191) (Time 0.21)
# Successful extraction (Page 192) (Time 0.25)
# Successful extraction (Page 193) (Time 0.2)
# Successful extraction (Page 194) (Time 0.29)
# Successful extraction (Page 195) (Time 0.4)
# Successful extraction (Page 196) (Time 0.26)
# Successful extraction (Page 197) (Time 0.19)
# Successful extraction (Page 198) (Time 0.2)
# Successful extraction (Page 199) (Time 0.23)
# Successful extraction (Page 200) (Time 0.37)
# Successful extraction (Page 201) (Time 0.39)
# Successful extraction (Page 202) (Time 0.21)
# Successful extraction (Page 203) (Time 0.21)
# Successful extraction (Page 204) (Time 0.2)
# Successful extraction (Page 205) (Time 0.2)
# Successful extraction (Page 206) (Time 0.22)
# Successful extraction (Page 207) (Time 0.19)
# Successful extraction (Page 208) (Time 0.26)
# Successful extraction (Page 209) (Time 0.22)
# Successful extraction (Page 210) (Time 0.23)
# Successful extraction (Page 211) (Time 0.31)
# Successful extraction (Page 212) (Time 0.28)
# Successful extraction (Page 213) (Time 0.18)
# Successful extraction (Page 214) (Time 0.19)
# Successful extraction (Page 215) (Time 0.21)
# Successful extraction (Page 216) (Time 0.18)
# Successful extraction (Page 217) (Time 0.24)
# Successful extraction (Page 218) (Time 0.2)
# Successful extraction (Page 219) (Time 0.2)
# Successful extraction (Page 220) (Time 0.21)
# Successful extraction (Page 221) (Time 0.23)
# Successful extraction (Page 222) (Time 0.28)
# Successful extraction (Page 223) (Time 0.23)
# Successful extraction (Page 224) (Time 0.24)
# Successful extraction (Page 225) (Time 0.28)
# Successful extraction (Page 226) (Time 0.4)
# Successful extraction (Page 227) (Time 0.19)
# Successful extraction (Page 228) (Time 0.21)
# Successful extraction (Page 229) (Time 0.19)
# Successful extraction (Page 230) (Time 0.19)
# Successful extraction (Page 231) (Time 0.21)
# Successful extraction (Page 232) (Time 0.27)
# Successful extraction (Page 233) (Time 0.2)
# Successful extraction (Page 234) (Time 0.29)
# Successful extraction (Page 235) (Time 0.23)
# Successful extraction (Page 236) (Time 0.23)
# Successful extraction (Page 237) (Time 0.2)
# Successful extraction (Page 238) (Time 0.23)
# Successful extraction (Page 239) (Time 0.25)
# Successful extraction (Page 240) (Time 0.27)
# Successful extraction (Page 241) (Time 0.24)
# Successful extraction (Page 242) (Time 0.19)
# Successful extraction (Page 243) (Time 0.19)
# Successful extraction (Page 244) (Time 0.25)
# Successful extraction (Page 245) (Time 0.17)
# Successful extraction (Page 246) (Time 0.21)
# Successful extraction (Page 247) (Time 0.36)
# Successful extraction (Page 248) (Time 0.24)
# Successful extraction (Page 249) (Time 0.21)
# Successful extraction (Page 250) (Time 0.25)
# Successful extraction (Page 251) (Time 0.23)
# Successful extraction (Page 252) (Time 0.21)
# Successful extraction (Page 253) (Time 0.24)
# Successful extraction (Page 254) (Time 0.2)
# Successful extraction (Page 255) (Time 0.26)
# Successful extraction (Page 256) (Time 0.2)
# Successful extraction (Page 257) (Time 0.22)
# Successful extraction (Page 258) (Time 0.2)
# Successful extraction (Page 259) (Time 0.2)
# Successful extraction (Page 260) (Time 0.24)
# Successful extraction (Page 261) (Time 0.21)
# Successful extraction (Page 262) (Time 0.32)
# Successful extraction (Page 263) (Time 0.25)
# Successful extraction (Page 264) (Time 0.26)
# Successful extraction (Page 265) (Time 0.2)
# Successful extraction (Page 266) (Time 0.23)
# Successful extraction (Page 267) (Time 0.21)
# Successful extraction (Page 268) (Time 0.24)
# Successful extraction (Page 269) (Time 0.18)
# Successful extraction (Page 270) (Time 0.42)
# Successful extraction (Page 271) (Time 0.23)
# Successful extraction (Page 272) (Time 0.48)
# Successful extraction (Page 273) (Time 0.22)
# Successful extraction (Page 274) (Time 0.22)
# Successful extraction (Page 275) (Time 0.2)
# Successful extraction (Page 276) (Time 0.19)
# Successful extraction (Page 277) (Time 0.26)
# Successful extraction (Page 278) (Time 0.2)
# Successful extraction (Page 279) (Time 0.32)
# Successful extraction (Page 280) (Time 0.2)
# Successful extraction (Page 281) (Time 0.18)
# Successful extraction (Page 282) (Time 0.23)
# Successful extraction (Page 283) (Time 0.43)
# Successful extraction (Page 284) (Time 0.23)
# Successful extraction (Page 285) (Time 0.21)
# Successful extraction (Page 286) (Time 0.21)
# Successful extraction (Page 287) (Time 0.19)
# Successful extraction (Page 288) (Time 0.22)
# Successful extraction (Page 289) (Time 0.25)
# Successful extraction (Page 290) (Time 0.23)
# Successful extraction (Page 291) (Time 0.21)
# Successful extraction (Page 292) (Time 0.24)
# Successful extraction (Page 293) (Time 0.22)
# Successful extraction (Page 294) (Time 0.26)
# Successful extraction (Page 295) (Time 0.2)
# Successful extraction (Page 296) (Time 0.23)
# Successful extraction (Page 297) (Time 0.64)
# Successful extraction (Page 298) (Time 0.23)
# Successful extraction (Page 299) (Time 0.23)
# Successful extraction (Page 300) (Time 0.27)
# Successful extraction (Page 301) (Time 0.26)
# Successful extraction (Page 302) (Time 0.23)
# Successful extraction (Page 303) (Time 0.24)
# Successful extraction (Page 304) (Time 0.23)
# Successful extraction (Page 305) (Time 0.26)
# Successful extraction (Page 306) (Time 0.22)
# Successful extraction (Page 307) (Time 0.2)
# Successful extraction (Page 308) (Time 0.23)
# Successful extraction (Page 309) (Time 0.25)
# Successful extraction (Page 310) (Time 0.28)
# Successful extraction (Page 311) (Time 0.3)
# Successful extraction (Page 312) (Time 0.24)
# Successful extraction (Page 313) (Time 0.21)
# Successful extraction (Page 314) (Time 0.27)
# Successful extraction (Page 315) (Time 0.2)
# Successful extraction (Page 316) (Time 0.24)
# Successful extraction (Page 317) (Time 0.22)
# Successful extraction (Page 318) (Time 0.3)
# Successful extraction (Page 319) (Time 0.23)
# Successful extraction (Page 320) (Time 0.25)
# Successful extraction (Page 321) (Time 0.26)
# Successful extraction (Page 322) (Time 0.19)
# Successful extraction (Page 323) (Time 0.23)
# Successful extraction (Page 324) (Time 0.29)
# Successful extraction (Page 325) (Time 0.21)
# Successful extraction (Page 326) (Time 0.24)
# Successful extraction (Page 327) (Time 0.27)
# Successful extraction (Page 328) (Time 0.2)
# Successful extraction (Page 329) (Time 0.23)
# Successful extraction (Page 330) (Time 0.27)
# Successful extraction (Page 331) (Time 0.21)
# Successful extraction (Page 332) (Time 0.25)
# Successful extraction (Page 333) (Time 0.23)
# Successful extraction (Page 334) (Time 0.23)
# Successful extraction (Page 335) (Time 0.23)
# Successful extraction (Page 336) (Time 0.23)
# Successful extraction (Page 337) (Time 0.21)
# Successful extraction (Page 338) (Time 0.27)
# Successful extraction (Page 339) (Time 0.22)
# Successful extraction (Page 340) (Time 0.2)
# Successful extraction (Page 341) (Time 0.26)
# Successful extraction (Page 342) (Time 0.21)
# Successful extraction (Page 343) (Time 0.22)
# Successful extraction (Page 344) (Time 0.26)
# Successful extraction (Page 345) (Time 0.25)
# Successful extraction (Page 346) (Time 0.26)
# Successful extraction (Page 347) (Time 0.21)
# Successful extraction (Page 348) (Time 0.23)
# Successful extraction (Page 349) (Time 0.2)
# Successful extraction (Page 350) (Time 0.22)
# Successful extraction (Page 351) (Time 0.22)
# Successful extraction (Page 352) (Time 0.26)
# Successful extraction (Page 353) (Time 0.3)
# Successful extraction (Page 354) (Time 0.25)
# Successful extraction (Page 355) (Time 0.22)
# Successful extraction (Page 356) (Time 0.25)
# Successful extraction (Page 357) (Time 0.2)
# Successful extraction (Page 358) (Time 0.21)
# Successful extraction (Page 359) (Time 0.25)
# Successful extraction (Page 360) (Time 0.21)
# Successful extraction (Page 361) (Time 0.25)
# Successful extraction (Page 362) (Time 0.28)
# Successful extraction (Page 363) (Time 0.22)
# Successful extraction (Page 364) (Time 0.21)
# Successful extraction (Page 365) (Time 0.22)
# Successful extraction (Page 366) (Time 0.23)
# Successful extraction (Page 367) (Time 0.2)
# Successful extraction (Page 368) (Time 0.22)
# Successful extraction (Page 369) (Time 0.28)
# Successful extraction (Page 370) (Time 0.22)
# Successful extraction (Page 371) (Time 0.2)
# Successful extraction (Page 372) (Time 0.19)
# Successful extraction (Page 373) (Time 0.27)
# Successful extraction (Page 374) (Time 0.27)
# Successful extraction (Page 375) (Time 0.21)
# Successful extraction (Page 376) (Time 0.22)
# Successful extraction (Page 377) (Time 0.21)
# Successful extraction (Page 378) (Time 0.21)
# Successful extraction (Page 379) (Time 0.29)
# Successful extraction (Page 380) (Time 0.24)
# Successful extraction (Page 381) (Time 0.22)
# Successful extraction (Page 382) (Time 0.28)
# Successful extraction (Page 383) (Time 0.24)
# Successful extraction (Page 384) (Time 0.25)
# Successful extraction (Page 385) (Time 0.21)
# Successful extraction (Page 386) (Time 0.22)
# Successful extraction (Page 387) (Time 0.31)
# Successful extraction (Page 388) (Time 0.2)
# Successful extraction (Page 389) (Time 0.25)
# Successful extraction (Page 390) (Time 0.21)
# Successful extraction (Page 391) (Time 0.23)
# Successful extraction (Page 392) (Time 0.22)
# Successful extraction (Page 393) (Time 0.24)
# Successful extraction (Page 394) (Time 0.3)
# Successful extraction (Page 395) (Time 0.22)
# Successful extraction (Page 396) (Time 0.23)
# Successful extraction (Page 397) (Time 0.22)
# Successful extraction (Page 398) (Time 0.24)
# Successful extraction (Page 399) (Time 0.23)
# Successful extraction (Page 400) (Time 0.24)
# Successful extraction (Page 401) (Time 0.23)
# Successful extraction (Page 402) (Time 0.23)
# Successful extraction (Page 403) (Time 0.21)
# Successful extraction (Page 404) (Time 0.23)
# Successful extraction (Page 405) (Time 0.22)
# Successful extraction (Page 406) (Time 0.23)
# Successful extraction (Page 407) (Time 0.23)
# Successful extraction (Page 408) (Time 0.28)
# Successful extraction (Page 409) (Time 0.22)
# Successful extraction (Page 410) (Time 0.24)
# Successful extraction (Page 411) (Time 0.25)
# Successful extraction (Page 412) (Time 0.23)
# Successful extraction (Page 413) (Time 0.22)
# Successful extraction (Page 414) (Time 0.24)
# Successful extraction (Page 415) (Time 0.24)
# Successful extraction (Page 416) (Time 0.26)
# Successful extraction (Page 417) (Time 0.31)
# Successful extraction (Page 418) (Time 0.23)
# Successful extraction (Page 419) (Time 0.23)
# Successful extraction (Page 420) (Time 0.3)
# Successful extraction (Page 421) (Time 0.4)
# Successful extraction (Page 422) (Time 0.28)
# Successful extraction (Page 423) (Time 0.24)
# Successful extraction (Page 424) (Time 0.24)
# Successful extraction (Page 425) (Time 0.34)
# Successful extraction (Page 426) (Time 0.25)
# Successful extraction (Page 427) (Time 0.3)
# Successful extraction (Page 428) (Time 0.2)
# Successful extraction (Page 429) (Time 0.31)
# Successful extraction (Page 430) (Time 0.46)
# Successful extraction (Page 431) (Time 0.25)
# Successful extraction (Page 432) (Time 0.25)
# Successful extraction (Page 433) (Time 0.28)
# Successful extraction (Page 434) (Time 0.23)
# Successful extraction (Page 435) (Time 0.29)
# Successful extraction (Page 436) (Time 0.26)
# Successful extraction (Page 437) (Time 0.26)
# Successful extraction (Page 438) (Time 0.23)
# Successful extraction (Page 439) (Time 0.26)
# Successful extraction (Page 440) (Time 0.59)
# Successful extraction (Page 441) (Time 0.22)
# Successful extraction (Page 442) (Time 0.24)
# Successful extraction (Page 443) (Time 0.22)
# Successful extraction (Page 444) (Time 0.58)
# Successful extraction (Page 445) (Time 0.24)
# Successful extraction (Page 446) (Time 0.26)
# Successful extraction (Page 447) (Time 0.22)
# Successful extraction (Page 448) (Time 0.31)
# Successful extraction (Page 449) (Time 0.25)
# Successful extraction (Page 450) (Time 0.3)
# Successful extraction (Page 451) (Time 0.25)
# Successful extraction (Page 452) (Time 0.29)
# Successful extraction (Page 453) (Time 0.22)
# Successful extraction (Page 454) (Time 0.31)
# Successful extraction (Page 455) (Time 0.21)
# Successful extraction (Page 456) (Time 0.25)
# Successful extraction (Page 457) (Time 0.25)
# Successful extraction (Page 458) (Time 0.28)
# Successful extraction (Page 459) (Time 0.21)
# Successful extraction (Page 460) (Time 0.32)
# Successful extraction (Page 461) (Time 0.26)
# Successful extraction (Page 462) (Time 0.23)
# Successful extraction (Page 463) (Time 0.26)
# Successful extraction (Page 464) (Time 0.21)
# Successful extraction (Page 465) (Time 0.25)
# Successful extraction (Page 466) (Time 0.31)
# Successful extraction (Page 467) (Time 0.3)
# Successful extraction (Page 468) (Time 0.24)
# Successful extraction (Page 469) (Time 0.24)
# Successful extraction (Page 470) (Time 0.27)
# Successful extraction (Page 471) (Time 0.25)
# Successful extraction (Page 472) (Time 0.25)
# Successful extraction (Page 473) (Time 0.25)
# Successful extraction (Page 474) (Time 0.22)
# Successful extraction (Page 475) (Time 0.22)
# Successful extraction (Page 476) (Time 0.21)
# Successful extraction (Page 477) (Time 0.24)
# Successful extraction (Page 478) (Time 0.26)
# Successful extraction (Page 479) (Time 0.3)
# Successful extraction (Page 480) (Time 0.25)
# Successful extraction (Page 481) (Time 0.24)
# Successful extraction (Page 482) (Time 0.28)
# Successful extraction (Page 483) (Time 0.25)
# Successful extraction (Page 484) (Time 0.24)
# Successful extraction (Page 485) (Time 0.21)
# Successful extraction (Page 486) (Time 0.3)
# Successful extraction (Page 487) (Time 0.28)
# Successful extraction (Page 488) (Time 0.24)
# Successful extraction (Page 489) (Time 0.24)
# Successful extraction (Page 490) (Time 0.33)
# Successful extraction (Page 491) (Time 0.28)
# Successful extraction (Page 492) (Time 0.22)
# Successful extraction (Page 493) (Time 0.25)
# Successful extraction (Page 494) (Time 0.23)
# Successful extraction (Page 495) (Time 0.25)
# Successful extraction (Page 496) (Time 0.24)
# Successful extraction (Page 497) (Time 0.3)
# Successful extraction (Page 498) (Time 0.25)
# Successful extraction (Page 499) (Time 0.3)
# Successful extraction (Page 500) (Time 0.21)
# Successful extraction (Page 501) (Time 0.25)
# Successful extraction (Page 502) (Time 0.3)
# Successful extraction (Page 503) (Time 0.23)
# Successful extraction (Page 504) (Time 0.25)
# Successful extraction (Page 505) (Time 0.23)
# Successful extraction (Page 506) (Time 0.24)
# Successful extraction (Page 507) (Time 0.33)
# Successful extraction (Page 508) (Time 0.26)
# Successful extraction (Page 509) (Time 0.23)
# Successful extraction (Page 510) (Time 0.45)
# Successful extraction (Page 511) (Time 0.27)
# Successful extraction (Page 512) (Time 0.25)
# Successful extraction (Page 513) (Time 0.27)
# Successful extraction (Page 514) (Time 0.28)
# Successful extraction (Page 515) (Time 0.25)
# Successful extraction (Page 516) (Time 0.28)
# Successful extraction (Page 517) (Time 0.26)
# Successful extraction (Page 518) (Time 0.24)
# Successful extraction (Page 519) (Time 0.22)
# Successful extraction (Page 520) (Time 0.25)
# Successful extraction (Page 521) (Time 0.24)
# Successful extraction (Page 522) (Time 0.28)
# Successful extraction (Page 523) (Time 0.3)
# Successful extraction (Page 524) (Time 0.25)
# Successful extraction (Page 525) (Time 0.31)
# Successful extraction (Page 526) (Time 0.28)
# Successful extraction (Page 527) (Time 0.26)
# Successful extraction (Page 528) (Time 0.24)
# Successful extraction (Page 529) (Time 0.27)
# Successful extraction (Page 530) (Time 0.28)
# Successful extraction (Page 531) (Time 0.25)
# Successful extraction (Page 532) (Time 0.24)
# Successful extraction (Page 533) (Time 0.27)
# Successful extraction (Page 534) (Time 0.27)
# Successful extraction (Page 535) (Time 0.26)
# Successful extraction (Page 536) (Time 0.27)
# Successful extraction (Page 537) (Time 0.24)
# Successful extraction (Page 538) (Time 0.22)
# Successful extraction (Page 539) (Time 0.25)
# Successful extraction (Page 540) (Time 0.24)
# Successful extraction (Page 541) (Time 0.25)
# Successful extraction (Page 542) (Time 0.28)
# Successful extraction (Page 543) (Time 0.34)
# Successful extraction (Page 544) (Time 0.23)
# Successful extraction (Page 545) (Time 0.25)
# Successful extraction (Page 546) (Time 0.26)
# Successful extraction (Page 547) (Time 0.24)
# Successful extraction (Page 548) (Time 0.26)
# Successful extraction (Page 549) (Time 0.26)
# Successful extraction (Page 550) (Time 0.24)
# Successful extraction (Page 551) (Time 0.24)
# Successful extraction (Page 552) (Time 0.23)
# Successful extraction (Page 553) (Time 0.27)
# Successful extraction (Page 554) (Time 0.24)
# Successful extraction (Page 555) (Time 0.25)
# Successful extraction (Page 556) (Time 0.26)
# Successful extraction (Page 557) (Time 0.2)
# Successful extraction (Page 558) (Time 0.27)
# Successful extraction (Page 559) (Time 0.25)
# Successful extraction (Page 560) (Time 0.29)
# Successful extraction (Page 561) (Time 0.26)
# Successful extraction (Page 562) (Time 0.24)
# Successful extraction (Page 563) (Time 0.24)
# Successful extraction (Page 564) (Time 0.29)
# Successful extraction (Page 565) (Time 0.23)
# Successful extraction (Page 566) (Time 0.24)
# Successful extraction (Page 567) (Time 0.25)
# Successful extraction (Page 568) (Time 0.33)
# Successful extraction (Page 569) (Time 0.27)
# Successful extraction (Page 570) (Time 0.25)
# Successful extraction (Page 571) (Time 0.23)
# Successful extraction (Page 572) (Time 0.27)
# Successful extraction (Page 573) (Time 0.3)
# Successful extraction (Page 574) (Time 0.35)
# Successful extraction (Page 575) (Time 0.25)
# Successful extraction (Page 576) (Time 0.26)
# Successful extraction (Page 577) (Time 0.26)
# Successful extraction (Page 578) (Time 0.25)
# Successful extraction (Page 579) (Time 0.25)
# Successful extraction (Page 580) (Time 0.24)
# Successful extraction (Page 581) (Time 0.27)
# Successful extraction (Page 582) (Time 0.24)
# Successful extraction (Page 583) (Time 0.28)
# Successful extraction (Page 584) (Time 0.26)
# Successful extraction (Page 585) (Time 0.26)
# Successful extraction (Page 586) (Time 0.25)
# Successful extraction (Page 587) (Time 0.3)
# Successful extraction (Page 588) (Time 0.32)
# Successful extraction (Page 589) (Time 0.32)
# Successful extraction (Page 590) (Time 0.32)
# Successful extraction (Page 591) (Time 0.3)
# Successful extraction (Page 592) (Time 0.35)
# Successful extraction (Page 593) (Time 0.29)
# Successful extraction (Page 594) (Time 0.35)
# Successful extraction (Page 595) (Time 0.28)
# Successful extraction (Page 596) (Time 0.21)
# Successful extraction (Page 597) (Time 0.28)
# Successful extraction (Page 598) (Time 0.25)
# Successful extraction (Page 599) (Time 0.27)
# Successful extraction (Page 600) (Time 0.3)
# Successful extraction (Page 601) (Time 0.36)
# Successful extraction (Page 602) (Time 0.28)
# Successful extraction (Page 603) (Time 0.33)
# Successful extraction (Page 604) (Time 0.25)
# Successful extraction (Page 605) (Time 0.29)
# Successful extraction (Page 606) (Time 0.27)
# Successful extraction (Page 607) (Time 0.33)
# Successful extraction (Page 608) (Time 0.28)
# Successful extraction (Page 609) (Time 0.3)
# Successful extraction (Page 610) (Time 0.26)
# Successful extraction (Page 611) (Time 0.47)
# Successful extraction (Page 612) (Time 0.25)
# Successful extraction (Page 613) (Time 0.29)
# Successful extraction (Page 614) (Time 0.27)
# Successful extraction (Page 615) (Time 0.3)
# Successful extraction (Page 616) (Time 0.26)
# Successful extraction (Page 617) (Time 0.23)
# Successful extraction (Page 618) (Time 0.25)
# Successful extraction (Page 619) (Time 0.35)
# Successful extraction (Page 620) (Time 0.28)
# Successful extraction (Page 621) (Time 0.29)
# Successful extraction (Page 622) (Time 0.26)
# Successful extraction (Page 623) (Time 0.23)
# Successful extraction (Page 624) (Time 0.37)
# Successful extraction (Page 625) (Time 0.25)
# Successful extraction (Page 626) (Time 0.24)
# Successful extraction (Page 627) (Time 0.27)
# Successful extraction (Page 628) (Time 0.3)
# Successful extraction (Page 629) (Time 0.27)
# Successful extraction (Page 630) (Time 0.3)
# Successful extraction (Page 631) (Time 0.26)
# Successful extraction (Page 632) (Time 0.36)
# Successful extraction (Page 633) (Time 0.27)
# Successful extraction (Page 634) (Time 0.25)
# Successful extraction (Page 635) (Time 0.28)
# Successful extraction (Page 636) (Time 0.26)
# Successful extraction (Page 637) (Time 0.27)
# Successful extraction (Page 638) (Time 0.3)
# Successful extraction (Page 639) (Time 0.31)
# Successful extraction (Page 640) (Time 0.28)
# Successful extraction (Page 641) (Time 0.25)
# Successful extraction (Page 642) (Time 0.32)
# Successful extraction (Page 643) (Time 0.3)
# Successful extraction (Page 644) (Time 0.24)
# Successful extraction (Page 645) (Time 0.25)
# Successful extraction (Page 646) (Time 0.28)
# Successful extraction (Page 647) (Time 0.28)
# Successful extraction (Page 648) (Time 0.25)
# Successful extraction (Page 649) (Time 0.29)
# Successful extraction (Page 650) (Time 0.41)
# Successful extraction (Page 651) (Time 0.27)
# Successful extraction (Page 652) (Time 0.26)
# Successful extraction (Page 653) (Time 0.25)
# Successful extraction (Page 654) (Time 0.24)
# Successful extraction (Page 655) (Time 0.24)
# Successful extraction (Page 656) (Time 0.27)
# Successful extraction (Page 657) (Time 0.25)
# Successful extraction (Page 658) (Time 0.27)
# Successful extraction (Page 659) (Time 0.26)
# Successful extraction (Page 660) (Time 0.27)
# Successful extraction (Page 661) (Time 0.25)
# Successful extraction (Page 662) (Time 0.26)
# Successful extraction (Page 663) (Time 0.33)
# Successful extraction (Page 664) (Time 0.28)
# Successful extraction (Page 665) (Time 0.27)
# Successful extraction (Page 666) (Time 0.27)
# Successful extraction (Page 667) (Time 0.32)
# Successful extraction (Page 668) (Time 0.29)
# Successful extraction (Page 669) (Time 0.25)
# Successful extraction (Page 670) (Time 0.29)
# Successful extraction (Page 671) (Time 0.24)
# Successful extraction (Page 672) (Time 0.27)
# Successful extraction (Page 673) (Time 0.25)
# Successful extraction (Page 674) (Time 0.28)
# Successful extraction (Page 675) (Time 0.25)
# Successful extraction (Page 676) (Time 0.26)
# Successful extraction (Page 677) (Time 0.27)
# Successful extraction (Page 678) (Time 0.5)
# Successful extraction (Page 679) (Time 0.27)
# Successful extraction (Page 680) (Time 0.29)
# Successful extraction (Page 681) (Time 0.33)
# Successful extraction (Page 682) (Time 0.27)
# Successful extraction (Page 683) (Time 0.29)
# Successful extraction (Page 684) (Time 0.29)
# Successful extraction (Page 685) (Time 0.27)
# Successful extraction (Page 686) (Time 0.27)
# Successful extraction (Page 687) (Time 0.27)
# Successful extraction (Page 688) (Time 0.26)
# Successful extraction (Page 689) (Time 0.26)
# Successful extraction (Page 690) (Time 0.29)
# Successful extraction (Page 691) (Time 0.26)
# Successful extraction (Page 692) (Time 0.3)
# Successful extraction (Page 693) (Time 0.37)
# Successful extraction (Page 694) (Time 0.34)
# Successful extraction (Page 695) (Time 0.29)
# Successful extraction (Page 696) (Time 0.29)
# Successful extraction (Page 697) (Time 0.34)
# Successful extraction (Page 698) (Time 0.37)
# Successful extraction (Page 699) (Time 0.35)
# Successful extraction (Page 700) (Time 0.26)
# Successful extraction (Page 701) (Time 0.28)
# Successful extraction (Page 702) (Time 0.27)
# Successful extraction (Page 703) (Time 0.32)
# Successful extraction (Page 704) (Time 0.32)
# Successful extraction (Page 705) (Time 0.27)
# Successful extraction (Page 706) (Time 0.29)
# Successful extraction (Page 707) (Time 0.31)
# Successful extraction (Page 708) (Time 0.3)
# Successful extraction (Page 709) (Time 0.29)
# Successful extraction (Page 710) (Time 0.3)
# Successful extraction (Page 711) (Time 0.26)
# Successful extraction (Page 712) (Time 0.27)
# Successful extraction (Page 713) (Time 0.31)
# Successful extraction (Page 714) (Time 0.31)
# Successful extraction (Page 715) (Time 0.28)
# Successful extraction (Page 716) (Time 0.33)
# Successful extraction (Page 717) (Time 0.28)
# Successful extraction (Page 718) (Time 0.34)
# Successful extraction (Page 719) (Time 0.26)
# Successful extraction (Page 720) (Time 0.34)
# Successful extraction (Page 721) (Time 0.3)
# Successful extraction (Page 722) (Time 0.32)
# Successful extraction (Page 723) (Time 0.28)
# Successful extraction (Page 724) (Time 0.27)
# Successful extraction (Page 725) (Time 0.73)
# Successful extraction (Page 726) (Time 0.27)
# Successful extraction (Page 727) (Time 0.33)
# Successful extraction (Page 728) (Time 0.3)
# Successful extraction (Page 729) (Time 0.25)
# Successful extraction (Page 730) (Time 0.28)
# Successful extraction (Page 731) (Time 0.26)
# Successful extraction (Page 732) (Time 0.26)
# Successful extraction (Page 733) (Time 0.52)
# Successful extraction (Page 734) (Time 0.26)
# Successful extraction (Page 735) (Time 0.29)
# Successful extraction (Page 736) (Time 0.79)
# Successful extraction (Page 737) (Time 0.3)
# Successful extraction (Page 738) (Time 0.27)
# Successful extraction (Page 739) (Time 0.26)
# Successful extraction (Page 740) (Time 0.25)
# Successful extraction (Page 741) (Time 0.31)
# Successful extraction (Page 742) (Time 0.28)
# Successful extraction (Page 743) (Time 0.29)
# Successful extraction (Page 744) (Time 0.27)
# Successful extraction (Page 745) (Time 0.28)
# Successful extraction (Page 746) (Time 0.27)
# Successful extraction (Page 747) (Time 0.26)
# Successful extraction (Page 748) (Time 0.35)
# Successful extraction (Page 749) (Time 0.34)
# Successful extraction (Page 750) (Time 0.35)
# Successful extraction (Page 751) (Time 0.29)
# Successful extraction (Page 752) (Time 0.28)
# Successful extraction (Page 753) (Time 0.28)
# Successful extraction (Page 754) (Time 0.3)
# Successful extraction (Page 755) (Time 0.33)
# Successful extraction (Page 756) (Time 0.37)
# Successful extraction (Page 757) (Time 0.28)
# Successful extraction (Page 758) (Time 0.3)
# Successful extraction (Page 759) (Time 0.28)
# Successful extraction (Page 760) (Time 0.28)
# Successful extraction (Page 761) (Time 0.33)
# Successful extraction (Page 762) (Time 0.3)
# Successful extraction (Page 763) (Time 0.25)
# Successful extraction (Page 764) (Time 0.3)
# Successful extraction (Page 765) (Time 0.3)
# Successful extraction (Page 766) (Time 0.35)
# Successful extraction (Page 767) (Time 0.26)
# Successful extraction (Page 768) (Time 0.3)
# Successful extraction (Page 769) (Time 0.36)
# Successful extraction (Page 770) (Time 0.31)
# Successful extraction (Page 771) (Time 0.27)
# Successful extraction (Page 772) (Time 0.26)
# Successful extraction (Page 773) (Time 0.24)
# Successful extraction (Page 774) (Time 0.3)
# Successful extraction (Page 775) (Time 0.26)
# Successful extraction (Page 776) (Time 0.31)
# Successful extraction (Page 777) (Time 0.24)
# Successful extraction (Page 778) (Time 0.28)
# Successful extraction (Page 779) (Time 0.28)
# Successful extraction (Page 780) (Time 0.28)
# Successful extraction (Page 781) (Time 0.33)
# Successful extraction (Page 782) (Time 0.28)
# Successful extraction (Page 783) (Time 0.33)
# Successful extraction (Page 784) (Time 0.29)
# Successful extraction (Page 785) (Time 0.29)
# Successful extraction (Page 786) (Time 0.29)
# Successful extraction (Page 787) (Time 0.27)
# Successful extraction (Page 788) (Time 0.3)
# Successful extraction (Page 789) (Time 0.3)
# Successful extraction (Page 790) (Time 0.27)
# Successful extraction (Page 791) (Time 0.26)
# Successful extraction (Page 792) (Time 0.3)
# Successful extraction (Page 793) (Time 0.34)
# Successful extraction (Page 794) (Time 0.27)
# Successful extraction (Page 795) (Time 0.29)
# Successful extraction (Page 796) (Time 0.3)
# Successful extraction (Page 797) (Time 0.3)
# Successful extraction (Page 798) (Time 0.28)
# Successful extraction (Page 799) (Time 0.3)
# Successful extraction (Page 800) (Time 0.34)
# Successful extraction (Page 801) (Time 0.3)
# Successful extraction (Page 802) (Time 0.32)
# Successful extraction (Page 803) (Time 0.3)
# Successful extraction (Page 804) (Time 0.31)
# Successful extraction (Page 805) (Time 0.33)
# Successful extraction (Page 806) (Time 0.35)
# Successful extraction (Page 807) (Time 0.26)
# Successful extraction (Page 808) (Time 0.32)
# Successful extraction (Page 809) (Time 0.3)
# Successful extraction (Page 810) (Time 0.29)
# Successful extraction (Page 811) (Time 0.29)
# Successful extraction (Page 812) (Time 0.27)
# Successful extraction (Page 813) (Time 0.32)
# Successful extraction (Page 814) (Time 0.25)
# Successful extraction (Page 815) (Time 0.31)
# Successful extraction (Page 816) (Time 0.53)
# Successful extraction (Page 817) (Time 0.3)
# Successful extraction (Page 818) (Time 0.29)
# Successful extraction (Page 819) (Time 0.34)
# Successful extraction (Page 820) (Time 0.29)
# Successful extraction (Page 821) (Time 0.28)
# Successful extraction (Page 822) (Time 0.26)
# Successful extraction (Page 823) (Time 0.3)
# Successful extraction (Page 824) (Time 0.3)
# Successful extraction (Page 825) (Time 0.28)
# Successful extraction (Page 826) (Time 0.32)
# Successful extraction (Page 827) (Time 0.29)
# Successful extraction (Page 828) (Time 0.33)
# Successful extraction (Page 829) (Time 0.35)
# Successful extraction (Page 830) (Time 0.54)
# Successful extraction (Page 831) (Time 0.27)
# Successful extraction (Page 832) (Time 0.3)
# Successful extraction (Page 833) (Time 0.36)
# Successful extraction (Page 834) (Time 0.33)
# Successful extraction (Page 835) (Time 0.28)
# Successful extraction (Page 836) (Time 0.3)
# Successful extraction (Page 837) (Time 0.27)
# Successful extraction (Page 838) (Time 0.3)
# Successful extraction (Page 839) (Time 0.28)
# Successful extraction (Page 840) (Time 0.29)
# Successful extraction (Page 841) (Time 0.29)
# Successful extraction (Page 842) (Time 0.29)
# Successful extraction (Page 843) (Time 0.28)
# Successful extraction (Page 844) (Time 0.27)
# Successful extraction (Page 845) (Time 0.26)
# Successful extraction (Page 846) (Time 0.28)
# Successful extraction (Page 847) (Time 0.29)
# Successful extraction (Page 848) (Time 0.3)
# Successful extraction (Page 849) (Time 0.31)
# Successful extraction (Page 850) (Time 0.36)
# Successful extraction (Page 851) (Time 0.27)
# Successful extraction (Page 852) (Time 0.29)
# Successful extraction (Page 853) (Time 0.3)
# Successful extraction (Page 854) (Time 0.33)
# Successful extraction (Page 855) (Time 0.3)
# Successful extraction (Page 856) (Time 0.29)
# Successful extraction (Page 857) (Time 0.31)
# Successful extraction (Page 858) (Time 0.36)
# Successful extraction (Page 859) (Time 0.31)
# Successful extraction (Page 860) (Time 0.37)
# Successful extraction (Page 861) (Time 0.33)
# Successful extraction (Page 862) (Time 0.34)
# Successful extraction (Page 863) (Time 0.33)
# Successful extraction (Page 864) (Time 0.38)
# Successful extraction (Page 865) (Time 0.34)
# Successful extraction (Page 866) (Time 0.27)
# Successful extraction (Page 867) (Time 0.25)
# Successful extraction (Page 868) (Time 0.33)
# Successful extraction (Page 869) (Time 0.54)
# Successful extraction (Page 870) (Time 0.34)
# Successful extraction (Page 871) (Time 0.29)
# Successful extraction (Page 872) (Time 0.27)
# Successful extraction (Page 873) (Time 0.32)
# Successful extraction (Page 874) (Time 0.35)
# Successful extraction (Page 875) (Time 0.36)
# Successful extraction (Page 876) (Time 0.34)
# Successful extraction (Page 877) (Time 0.33)
# Successful extraction (Page 878) (Time 0.33)
# Successful extraction (Page 879) (Time 0.34)
# Successful extraction (Page 880) (Time 0.33)
# Successful extraction (Page 881) (Time 0.37)
# Successful extraction (Page 882) (Time 0.31)
# Successful extraction (Page 883) (Time 0.33)
# Successful extraction (Page 884) (Time 0.27)
# Successful extraction (Page 885) (Time 0.3)
# Successful extraction (Page 886) (Time 0.32)
# Successful extraction (Page 887) (Time 0.27)
# Successful extraction (Page 888) (Time 0.28)
# Successful extraction (Page 889) (Time 0.29)
# Successful extraction (Page 890) (Time 0.29)
# Successful extraction (Page 891) (Time 0.31)
# Successful extraction (Page 892) (Time 0.27)
# Successful extraction (Page 893) (Time 0.3)
# Successful extraction (Page 894) (Time 0.27)
# Successful extraction (Page 895) (Time 0.32)
# Successful extraction (Page 896) (Time 0.29)
# Successful extraction (Page 897) (Time 0.27)
# Successful extraction (Page 898) (Time 0.3)
# Successful extraction (Page 899) (Time 0.27)
# Successful extraction (Page 900) (Time 0.28)
# Successful extraction (Page 901) (Time 0.32)
# Successful extraction (Page 902) (Time 0.34)
# Successful extraction (Page 903) (Time 0.3)
# Successful extraction (Page 904) (Time 0.31)
# Successful extraction (Page 905) (Time 0.29)
# Successful extraction (Page 906) (Time 0.28)
# Successful extraction (Page 907) (Time 0.3)
# Successful extraction (Page 908) (Time 0.29)
# Successful extraction (Page 909) (Time 0.28)
# Successful extraction (Page 910) (Time 0.3)
# Successful extraction (Page 911) (Time 0.35)
# Successful extraction (Page 912) (Time 0.29)
# Successful extraction (Page 913) (Time 0.31)
# Successful extraction (Page 914) (Time 0.28)
# Successful extraction (Page 915) (Time 0.31)
# Successful extraction (Page 916) (Time 0.35)
# Successful extraction (Page 917) (Time 0.33)
# Successful extraction (Page 918) (Time 0.32)
# Successful extraction (Page 919) (Time 0.27)
# Successful extraction (Page 920) (Time 0.34)
# Successful extraction (Page 921) (Time 0.3)
# Successful extraction (Page 922) (Time 0.32)
# Successful extraction (Page 923) (Time 0.36)
# Successful extraction (Page 924) (Time 0.25)
# Successful extraction (Page 925) (Time 0.28)
# Successful extraction (Page 926) (Time 0.3)
# Successful extraction (Page 927) (Time 0.29)
# Successful extraction (Page 928) (Time 0.28)
# Successful extraction (Page 929) (Time 0.3)
# Successful extraction (Page 930) (Time 0.37)
# Successful extraction (Page 931) (Time 0.32)
# Successful extraction (Page 932) (Time 0.29)
# Successful extraction (Page 933) (Time 0.3)
# Successful extraction (Page 934) (Time 0.28)
# Successful extraction (Page 935) (Time 0.3)
# Successful extraction (Page 936) (Time 0.32)
# Successful extraction (Page 937) (Time 0.28)
# Successful extraction (Page 938) (Time 0.27)
# Successful extraction (Page 939) (Time 0.28)
# Successful extraction (Page 940) (Time 0.3)
# Successful extraction (Page 941) (Time 0.32)
# Successful extraction (Page 942) (Time 0.35)
# Successful extraction (Page 943) (Time 0.82)
# Successful extraction (Page 944) (Time 0.31)
# Successful extraction (Page 945) (Time 0.33)
# Successful extraction (Page 946) (Time 0.31)
# Successful extraction (Page 947) (Time 0.36)
# Successful extraction (Page 948) (Time 0.32)
# Successful extraction (Page 949) (Time 0.36)
# Successful extraction (Page 950) (Time 0.3)
# Successful extraction (Page 951) (Time 0.31)
# Successful extraction (Page 952) (Time 0.33)
# Successful extraction (Page 953) (Time 0.31)
# Successful extraction (Page 954) (Time 0.35)
# Successful extraction (Page 955) (Time 0.34)
# Successful extraction (Page 956) (Time 0.37)
# Successful extraction (Page 957) (Time 0.41)
# Successful extraction (Page 958) (Time 0.36)
# Successful extraction (Page 959) (Time 0.38)
# Successful extraction (Page 960) (Time 0.72)
# Successful extraction (Page 961) (Time 0.34)
# Successful extraction (Page 962) (Time 0.35)
# Successful extraction (Page 963) (Time 0.32)
# Successful extraction (Page 964) (Time 0.35)
# Successful extraction (Page 965) (Time 0.35)
# Successful extraction (Page 966) (Time 0.35)
# Successful extraction (Page 967) (Time 0.3)
# Successful extraction (Page 968) (Time 0.34)
# Successful extraction (Page 969) (Time 0.32)
# Successful extraction (Page 970) (Time 0.35)
# Successful extraction (Page 971) (Time 0.36)
# Successful extraction (Page 972) (Time 0.34)
# Successful extraction (Page 973) (Time 0.32)
# Successful extraction (Page 974) (Time 0.34)
# Successful extraction (Page 975) (Time 0.32)
# Successful extraction (Page 976) (Time 0.36)
# Successful extraction (Page 977) (Time 0.33)
# Successful extraction (Page 978) (Time 0.31)
# Successful extraction (Page 979) (Time 0.29)
# Successful extraction (Page 980) (Time 0.35)
# Successful extraction (Page 981) (Time 0.31)
# Successful extraction (Page 982) (Time 0.32)
# Successful extraction (Page 983) (Time 0.32)
# Successful extraction (Page 984) (Time 0.32)
# Successful extraction (Page 985) (Time 0.31)
# Successful extraction (Page 986) (Time 0.35)
# Successful extraction (Page 987) (Time 0.27)
# Successful extraction (Page 988) (Time 0.37)
# Successful extraction (Page 989) (Time 0.33)
# Successful extraction (Page 990) (Time 0.34)
# Successful extraction (Page 991) (Time 0.36)
# Successful extraction (Page 992) (Time 0.32)
# Successful extraction (Page 993) (Time 0.35)
# Successful extraction (Page 994) (Time 0.34)
# Successful extraction (Page 995) (Time 0.32)
# Successful extraction (Page 996) (Time 0.33)
# Successful extraction (Page 997) (Time 0.32)
# Successful extraction (Page 998) (Time 0.34)
# Successful extraction (Page 999) (Time 0.36)
# Successful extraction (Page 1000) (Time 0.37)
# Successful extraction (Page 1001) (Time 0.35)
# Successful extraction (Page 1002) (Time 0.3)
# Successful extraction (Page 1003) (Time 0.32)
# Successful extraction (Page 1004) (Time 0.32)
# Successful extraction (Page 1005) (Time 0.35)
# Successful extraction (Page 1006) (Time 0.33)
# Successful extraction (Page 1007) (Time 0.35)
# Successful extraction (Page 1008) (Time 0.32)
# Successful extraction (Page 1009) (Time 0.33)
# Successful extraction (Page 1010) (Time 0.32)
# Successful extraction (Page 1011) (Time 0.29)
# Successful extraction (Page 1012) (Time 0.33)
# Successful extraction (Page 1013) (Time 0.31)
# Successful extraction (Page 1014) (Time 0.32)
# Successful extraction (Page 1015) (Time 0.33)
# Successful extraction (Page 1016) (Time 0.35)
# Successful extraction (Page 1017) (Time 0.33)
# Successful extraction (Page 1018) (Time 0.31)
# Successful extraction (Page 1019) (Time 0.31)
# Successful extraction (Page 1020) (Time 0.31)
# Successful extraction (Page 1021) (Time 0.35)
# Successful extraction (Page 1022) (Time 0.36)
# Successful extraction (Page 1023) (Time 0.33)
# Successful extraction (Page 1024) (Time 0.32)
# Successful extraction (Page 1025) (Time 0.31)
# Successful extraction (Page 1026) (Time 0.29)
# Successful extraction (Page 1027) (Time 0.31)
# Successful extraction (Page 1028) (Time 0.33)
# Successful extraction (Page 1029) (Time 0.29)
# Successful extraction (Page 1030) (Time 0.37)
# Successful extraction (Page 1031) (Time 0.33)
# Successful extraction (Page 1032) (Time 0.33)
# Successful extraction (Page 1033) (Time 0.35)
# Successful extraction (Page 1034) (Time 0.33)
# Successful extraction (Page 1035) (Time 0.34)
# Successful extraction (Page 1036) (Time 0.28)
# Successful extraction (Page 1037) (Time 0.31)
# Successful extraction (Page 1038) (Time 0.39)
# Successful extraction (Page 1039) (Time 0.34)
# Successful extraction (Page 1040) (Time 0.33)
# Successful extraction (Page 1041) (Time 0.33)
# Successful extraction (Page 1042) (Time 0.32)
# Successful extraction (Page 1043) (Time 0.31)
# Successful extraction (Page 1044) (Time 0.33)
# Successful extraction (Page 1045) (Time 0.34)
# Successful extraction (Page 1046) (Time 0.32)
# Successful extraction (Page 1047) (Time 0.38)
# Successful extraction (Page 1048) (Time 0.31)
# Successful extraction (Page 1049) (Time 0.36)
# Successful extraction (Page 1050) (Time 0.68)
# Successful extraction (Page 1051) (Time 0.37)
# Successful extraction (Page 1052) (Time 0.32)
# Successful extraction (Page 1053) (Time 0.36)
# Successful extraction (Page 1054) (Time 0.34)
# Successful extraction (Page 1055) (Time 0.36)
# Successful extraction (Page 1056) (Time 0.3)
# Successful extraction (Page 1057) (Time 0.3)
# Successful extraction (Page 1058) (Time 0.3)
# Successful extraction (Page 1059) (Time 0.28)
# Successful extraction (Page 1060) (Time 0.35)
# Successful extraction (Page 1061) (Time 0.3)
# Successful extraction (Page 1062) (Time 0.28)
# Successful extraction (Page 1063) (Time 0.32)
# Successful extraction (Page 1064) (Time 0.33)
# Successful extraction (Page 1065) (Time 0.36)
# Successful extraction (Page 1066) (Time 0.32)
# Successful extraction (Page 1067) (Time 0.3)
# Successful extraction (Page 1068) (Time 0.39)
# Successful extraction (Page 1069) (Time 0.34)
# Successful extraction (Page 1070) (Time 0.34)
# ...
# Successful extraction (Page 2798) (Time 0.61)
# Successful extraction (Page 2799) (Time 0.54)
# Successful extraction (Page 2800) (Time 0.62)
# Successful extraction (Page 2801) (Time 0.58)
# Successful extraction (Page 2802) (Time 0.55)
# Successful extraction (Page 2803) (Time 0.52)
# Successful extraction (Page 2804) (Time 0.74)
# Successful extraction (Page 2805) (Time 0.57)
# Successful extraction (Page 2806) (Time 0.53)
# Successful extraction (Page 2807) (Time 0.56)
# Successful extraction (Page 2808) (Time 0.55)
# Successful extraction (Page 2809) (Time 0.54)
# Successful extraction (Page 2810) (Time 0.52)
# Successful extraction (Page 2811) (Time 0.49)
# Successful extraction (Page 2812) (Time 0.67)
# Successful extraction (Page 2813) (Time 0.54)
# Successful extraction (Page 2814) (Time 0.53)
# Successful extraction (Page 2815) (Time 0.56)
# Successful extraction (Page 2816) (Time 0.5)
# Successful extraction (Page 2817) (Time 0.56)
# Successful extraction (Page 2818) (Time 0.59)
# Successful extraction (Page 2819) (Time 0.54)
# Successful extraction (Page 2820) (Time 0.56)
# Successful extraction (Page 2821) (Time 0.51)
# Successful extraction (Page 2822) (Time 0.55)
# Successful extraction (Page 2823) (Time 0.52)
# Successful extraction (Page 2824) (Time 0.52)
# Successful extraction (Page 2825) (Time 0.55)
# Successful extraction (Page 2826) (Time 0.58)
# Successful extraction (Page 2827) (Time 0.54)
# Successful extraction (Page 2828) (Time 0.5)
# Successful extraction (Page 2829) (Time 0.56)
# Successful extraction (Page 2830) (Time 0.52)
# Successful extraction (Page 2831) (Time 0.56)
# Successful extraction (Page 2832) (Time 0.57)
# Successful extraction (Page 2833) (Time 0.51)
# Successful extraction (Page 2834) (Time 0.54)
# Successful extraction (Page 2835) (Time 0.55)
# Successful extraction (Page 2836) (Time 0.59)
# Successful extraction (Page 2837) (Time 0.53)
# Successful extraction (Page 2838) (Time 0.56)
# Successful extraction (Page 2839) (Time 0.53)
# Successful extraction (Page 2840) (Time 0.59)
# Successful extraction (Page 2841) (Time 0.55)
# Successful extraction (Page 2842) (Time 0.56)
# Successful extraction (Page 2843) (Time 0.55)
# Successful extraction (Page 2844) (Time 0.62)
# Successful extraction (Page 2845) (Time 0.63)
# Successful extraction (Page 2846) (Time 0.57)
# Successful extraction (Page 2847) (Time 0.77)
# Successful extraction (Page 2848) (Time 0.57)
# Successful extraction (Page 2849) (Time 0.53)
# Successful extraction (Page 2850) (Time 0.56)
# Successful extraction (Page 2851) (Time 0.58)
# Successful extraction (Page 2852) (Time 0.64)
# Successful extraction (Page 2853) (Time 0.6)
# Successful extraction (Page 2854) (Time 0.56)
# Successful extraction (Page 2855) (Time 0.6)
# Successful extraction (Page 2856) (Time 0.58)
# Successful extraction (Page 2857) (Time 0.59)
# Successful extraction (Page 2858) (Time 0.58)
# Successful extraction (Page 2859) (Time 0.53)
# Successful extraction (Page 2860) (Time 0.53)
# Successful extraction (Page 2861) (Time 0.53)
# Successful extraction (Page 2862) (Time 0.58)
# Successful extraction (Page 2863) (Time 0.57)
# Successful extraction (Page 2864) (Time 0.59)
# Successful extraction (Page 2865) (Time 0.57)
# Successful extraction (Page 2866) (Time 0.57)
# Successful extraction (Page 2867) (Time 0.54)
# Successful extraction (Page 2868) (Time 0.54)
# Successful extraction (Page 2869) (Time 0.64)
# Successful extraction (Page 2870) (Time 0.53)
# Successful extraction (Page 2871) (Time 0.52)
# Successful extraction (Page 2872) (Time 0.55)
# Successful extraction (Page 2873) (Time 0.57)
# Successful extraction (Page 2874) (Time 0.62)
# Successful extraction (Page 2875) (Time 0.51)
# Successful extraction (Page 2876) (Time 0.58)
# Successful extraction (Page 2877) (Time 0.74)
# Successful extraction (Page 2878) (Time 0.58)
# Successful extraction (Page 2879) (Time 0.53)
# Successful extraction (Page 2880) (Time 0.6)
# Successful extraction (Page 2881) (Time 0.53)
# Successful extraction (Page 2882) (Time 0.62)
# Successful extraction (Page 2883) (Time 0.6)
# Successful extraction (Page 2884) (Time 0.6)
# Successful extraction (Page 2885) (Time 0.57)
# Successful extraction (Page 2886) (Time 0.59)
# Successful extraction (Page 2887) (Time 0.55)
# Successful extraction (Page 2888) (Time 0.57)
# Successful extraction (Page 2889) (Time 0.55)
# Successful extraction (Page 2890) (Time 0.55)
# Successful extraction (Page 2891) (Time 0.57)
# Successful extraction (Page 2892) (Time 0.61)
# Successful extraction (Page 2893) (Time 0.55)
# Successful extraction (Page 2894) (Time 0.54)
# Successful extraction (Page 2895) (Time 0.55)
# Successful extraction (Page 2896) (Time 0.55)
# Successful extraction (Page 2897) (Time 0.58)
# Successful extraction (Page 2898) (Time 0.56)
# Successful extraction (Page 2899) (Time 0.56)
# Successful extraction (Page 2900) (Time 0.59)
# Successful extraction (Page 2901) (Time 0.54)
# Successful extraction (Page 2902) (Time 0.52)
# Successful extraction (Page 2903) (Time 0.57)
# Successful extraction (Page 2904) (Time 0.57)
# Successful extraction (Page 2905) (Time 0.63)
# Successful extraction (Page 2906) (Time 0.75)
# Successful extraction (Page 2907) (Time 0.76)
# Successful extraction (Page 2908) (Time 0.83)
# Successful extraction (Page 2909) (Time 0.55)
# Successful extraction (Page 2910) (Time 0.65)
# Successful extraction (Page 2911) (Time 0.72)
# Successful extraction (Page 2912) (Time 0.8)
# Successful extraction (Page 2913) (Time 0.62)
# Successful extraction (Page 2914) (Time 0.62)
# Successful extraction (Page 2915) (Time 0.58)
# Successful extraction (Page 2916) (Time 0.56)
# Successful extraction (Page 2917) (Time 0.64)
# Successful extraction (Page 2918) (Time 0.53)
# Successful extraction (Page 2919) (Time 0.61)
# Successful extraction (Page 2920) (Time 0.55)
# Successful extraction (Page 2921) (Time 0.6)
# Successful extraction (Page 2922) (Time 0.61)
# Successful extraction (Page 2923) (Time 0.58)
# Successful extraction (Page 2924) (Time 0.71)
# Successful extraction (Page 2925) (Time 0.56)
# Successful extraction (Page 2926) (Time 0.59)
# Successful extraction (Page 2927) (Time 0.55)
# Successful extraction (Page 2928) (Time 0.62)
# Successful extraction (Page 2929) (Time 0.53)
# Successful extraction (Page 2930) (Time 0.58)
# Successful extraction (Page 2931) (Time 0.55)
# Successful extraction (Page 2932) (Time 0.55)
# Successful extraction (Page 2933) (Time 0.58)
# Successful extraction (Page 2934) (Time 0.57)
# Successful extraction (Page 2935) (Time 0.59)
# Successful extraction (Page 2936) (Time 0.61)
# Successful extraction (Page 2937) (Time 0.56)
# Successful extraction (Page 2938) (Time 0.8)
# Successful extraction (Page 2939) (Time 0.57)
# Successful extraction (Page 2940) (Time 0.65)
# Successful extraction (Page 2941) (Time 0.65)
# Successful extraction (Page 2942) (Time 0.63)
# Successful extraction (Page 2943) (Time 0.59)
# Successful extraction (Page 2944) (Time 0.59)
# Successful extraction (Page 2945) (Time 0.56)
# Successful extraction (Page 2946) (Time 0.57)
# Successful extraction (Page 2947) (Time 0.58)
# Successful extraction (Page 2948) (Time 0.62)
# Successful extraction (Page 2949) (Time 0.56)
# Successful extraction (Page 2950) (Time 0.61)
# Successful extraction (Page 2951) (Time 0.56)
# Successful extraction (Page 2952) (Time 0.55)
# Successful extraction (Page 2953) (Time 0.65)
# Successful extraction (Page 2954) (Time 0.56)
# Successful extraction (Page 2955) (Time 0.59)
# Successful extraction (Page 2956) (Time 0.55)
# Successful extraction (Page 2957) (Time 0.66)
# Successful extraction (Page 2958) (Time 0.63)
# Successful extraction (Page 2959) (Time 0.59)
# Successful extraction (Page 2960) (Time 0.58)
# Successful extraction (Page 2961) (Time 0.59)
# Successful extraction (Page 2962) (Time 0.59)
# Successful extraction (Page 2963) (Time 1.05)
# Successful extraction (Page 2964) (Time 0.55)
# Successful extraction (Page 2965) (Time 0.63)
# Successful extraction (Page 2966) (Time 0.52)
# Successful extraction (Page 2967) (Time 0.66)
# Successful extraction (Page 2968) (Time 0.62)
# Successful extraction (Page 2969) (Time 0.56)
# Successful extraction (Page 2970) (Time 0.59)
# Successful extraction (Page 2971) (Time 0.62)
# Successful extraction (Page 2972) (Time 0.62)
# Successful extraction (Page 2973) (Time 0.54)
# Successful extraction (Page 2974) (Time 0.56)
# Successful extraction (Page 2975) (Time 0.54)
# Successful extraction (Page 2976) (Time 0.84)
# Successful extraction (Page 2977) (Time 0.71)
# Successful extraction (Page 2978) (Time 0.73)
# Successful extraction (Page 2979) (Time 0.59)
# Successful extraction (Page 2980) (Time 0.62)
# Successful extraction (Page 2981) (Time 0.59)
# Successful extraction (Page 2982) (Time 0.57)
# Successful extraction (Page 2983) (Time 0.6)
# Successful extraction (Page 2984) (Time 0.56)
# Successful extraction (Page 2985) (Time 0.68)
# Successful extraction (Page 2986) (Time 0.61)
# Successful extraction (Page 2987) (Time 0.64)
# Successful extraction (Page 2988) (Time 0.61)
# Successful extraction (Page 2989) (Time 0.58)
# Successful extraction (Page 2990) (Time 0.58)
# Successful extraction (Page 2991) (Time 0.59)
# Successful extraction (Page 2992) (Time 0.59)
# Successful extraction (Page 2993) (Time 0.76)
# Successful extraction (Page 2994) (Time 0.56)
# Successful extraction (Page 2995) (Time 0.58)
# Successful extraction (Page 2996) (Time 0.61)
# Successful extraction (Page 2997) (Time 0.67)
# Successful extraction (Page 2998) (Time 0.57)
# Successful extraction (Page 2999) (Time 0.59)
# Successful extraction (Page 3000) (Time 0.64)
# Successful extraction (Page 3001) (Time 0.58)
# Successful extraction (Page 3002) (Time 0.6)
# Successful extraction (Page 3003) (Time 0.6)
# Successful extraction (Page 3004) (Time 0.57)
# Successful extraction (Page 3005) (Time 0.72)
# Successful extraction (Page 3006) (Time 0.68)
# Successful extraction (Page 3007) (Time 0.55)
# Successful extraction (Page 3008) (Time 0.65)
# Successful extraction (Page 3009) (Time 0.62)
# Successful extraction (Page 3010) (Time 0.64)
# Successful extraction (Page 3011) (Time 0.58)
# Successful extraction (Page 3012) (Time 0.6)
# Successful extraction (Page 3013) (Time 0.68)
# Successful extraction (Page 3014) (Time 0.6)
# Successful extraction (Page 3015) (Time 0.81)
# Successful extraction (Page 3016) (Time 0.57)
# Successful extraction (Page 3017) (Time 0.58)
# Successful extraction (Page 3018) (Time 0.75)
# Successful extraction (Page 3019) (Time 0.58)
# Successful extraction (Page 3020) (Time 0.55)
# Successful extraction (Page 3021) (Time 0.57)
# Successful extraction (Page 3022) (Time 0.58)
# Successful extraction (Page 3023) (Time 0.58)
# Successful extraction (Page 3024) (Time 0.56)
# Successful extraction (Page 3025) (Time 0.6)
# Successful extraction (Page 3026) (Time 0.61)
# Successful extraction (Page 3027) (Time 0.62)
# Successful extraction (Page 3028) (Time 0.57)
# Successful extraction (Page 3029) (Time 0.63)
# Successful extraction (Page 3030) (Time 0.61)
# Successful extraction (Page 3031) (Time 0.56)
# Successful extraction (Page 3032) (Time 0.72)
# Successful extraction (Page 3033) (Time 0.59)
# Successful extraction (Page 3034) (Time 0.54)
# Successful extraction (Page 3035) (Time 0.64)
# Successful extraction (Page 3036) (Time 0.57)
# Successful extraction (Page 3037) (Time 0.58)
# Successful extraction (Page 3038) (Time 0.77)
# Successful extraction (Page 3039) (Time 0.56)
# Successful extraction (Page 3040) (Time 0.61)
# Successful extraction (Page 3041) (Time 0.56)
# Successful extraction (Page 3042) (Time 0.58)
# Successful extraction (Page 3043) (Time 0.55)
# Successful extraction (Page 3044) (Time 0.55)
# Successful extraction (Page 3045) (Time 0.88)
# Successful extraction (Page 3046) (Time 0.58)
# Successful extraction (Page 3047) (Time 0.59)
# Successful extraction (Page 3048) (Time 0.61)
# Successful extraction (Page 3049) (Time 0.67)
# Successful extraction (Page 3050) (Time 0.57)
# Successful extraction (Page 3051) (Time 0.66)
# Successful extraction (Page 3052) (Time 0.61)
# Successful extraction (Page 3053) (Time 0.6)
# Successful extraction (Page 3054) (Time 0.58)
# Successful extraction (Page 3055) (Time 0.65)
# Successful extraction (Page 3056) (Time 0.56)
# Successful extraction (Page 3057) (Time 0.66)
# Successful extraction (Page 3058) (Time 0.59)
# Successful extraction (Page 3059) (Time 0.54)
# Successful extraction (Page 3060) (Time 0.58)
# Successful extraction (Page 3061) (Time 0.59)
# Successful extraction (Page 3062) (Time 0.61)
# Successful extraction (Page 3063) (Time 0.65)
# Successful extraction (Page 3064) (Time 0.58)
# Successful extraction (Page 3065) (Time 0.67)
# Successful extraction (Page 3066) (Time 0.56)
# Successful extraction (Page 3067) (Time 0.59)
# Successful extraction (Page 3068) (Time 0.57)
# Successful extraction (Page 3069) (Time 0.55)
# Successful extraction (Page 3070) (Time 0.6)
# Successful extraction (Page 3071) (Time 0.58)
# Successful extraction (Page 3072) (Time 0.57)
# Successful extraction (Page 3073) (Time 0.57)
# Successful extraction (Page 3074) (Time 0.61)
# Successful extraction (Page 3075) (Time 0.55)
# Successful extraction (Page 3076) (Time 0.55)
# Successful extraction (Page 3077) (Time 0.59)
# Successful extraction (Page 3078) (Time 0.62)
# Successful extraction (Page 3079) (Time 0.6)
# Successful extraction (Page 3080) (Time 0.56)
# Successful extraction (Page 3081) (Time 0.62)
# Successful extraction (Page 3082) (Time 0.63)
# Successful extraction (Page 3083) (Time 0.6)
# Successful extraction (Page 3084) (Time 0.61)
# Successful extraction (Page 3085) (Time 1.12)
# Successful extraction (Page 3086) (Time 0.61)
# Successful extraction (Page 3087) (Time 0.6)
# Successful extraction (Page 3088) (Time 0.68)
# Successful extraction (Page 3089) (Time 0.57)
# Successful extraction (Page 3090) (Time 0.61)
# Successful extraction (Page 3091) (Time 0.7)
# Successful extraction (Page 3092) (Time 0.57)
# Successful extraction (Page 3093) (Time 0.57)
# Successful extraction (Page 3094) (Time 0.56)
# Successful extraction (Page 3095) (Time 0.6)
# Successful extraction (Page 3096) (Time 0.63)
# Successful extraction (Page 3097) (Time 0.62)
# Successful extraction (Page 3098) (Time 0.54)
# Successful extraction (Page 3099) (Time 0.94)
# Successful extraction (Page 3100) (Time 0.69)
# Successful extraction (Page 3101) (Time 0.64)
# Successful extraction (Page 3102) (Time 0.64)
# Successful extraction (Page 3103) (Time 0.6)
# Successful extraction (Page 3104) (Time 0.6)
# Successful extraction (Page 3105) (Time 0.6)
# Successful extraction (Page 3106) (Time 0.56)
# Successful extraction (Page 3107) (Time 0.62)
# Successful extraction (Page 3108) (Time 0.68)
# Successful extraction (Page 3109) (Time 0.56)
# Successful extraction (Page 3110) (Time 0.65)
# Successful extraction (Page 3111) (Time 0.63)
# Successful extraction (Page 3112) (Time 0.62)
# Successful extraction (Page 3113) (Time 0.66)
# Successful extraction (Page 3114) (Time 0.59)
# Successful extraction (Page 3115) (Time 0.59)
# Successful extraction (Page 3116) (Time 0.59)
# Successful extraction (Page 3117) (Time 0.61)
# Successful extraction (Page 3118) (Time 0.66)
# Successful extraction (Page 3119) (Time 0.61)
# Successful extraction (Page 3120) (Time 0.62)
# Successful extraction (Page 3121) (Time 0.59)
# Successful extraction (Page 3122) (Time 0.65)
# Successful extraction (Page 3123) (Time 0.57)
# Successful extraction (Page 3124) (Time 0.61)
# Successful extraction (Page 3125) (Time 0.62)
# Successful extraction (Page 3126) (Time 0.62)
# Successful extraction (Page 3127) (Time 0.59)
# Successful extraction (Page 3128) (Time 0.82)
# Successful extraction (Page 3129) (Time 0.62)
# Successful extraction (Page 3130) (Time 0.71)
# Successful extraction (Page 3131) (Time 0.6)
# Successful extraction (Page 3132) (Time 0.59)
# Successful extraction (Page 3133) (Time 0.6)
# Successful extraction (Page 3134) (Time 0.62)
# Successful extraction (Page 3135) (Time 0.58)
# Successful extraction (Page 3136) (Time 0.56)
# Successful extraction (Page 3137) (Time 0.51)
# Successful extraction (Page 3138) (Time 0.6)
# Successful extraction (Page 3139) (Time 0.56)
# Successful extraction (Page 3140) (Time 0.76)
# Successful extraction (Page 3141) (Time 0.63)
# Successful extraction (Page 3142) (Time 0.5)
#
# -----------------------------------------------------------------------------------------------------------------------
# Code duration: 1304.1 seconds

# %% [markdown]
# ------------------------------------------------
# <br>
# <br>
# <br>
#
#
# ## Data processing

# %%
dur = time.time()
file_url  = file_path + '11_data_structured_retrieved.csv'            
data = pd.read_csv(file_url)
# -------------------------------------------------------------------------------------~----------------------------------------

# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
print(f"unique: {(not data['stemmingzaak_stemming_Id'].duplicated().any())}")          # print duplicates
print(f"length: {len(data)}")                                                          # print length
print(data.iloc[0])                                                                    # print row
print((data.isna().sum()).to_frame())                                                  # print nulls
print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~


# -------------------------------------------------------------------------------------~----------------------------------------
# step 1: redefine column names
print("\n step 1: redefine column names")                                          # print step
print("-----------------------------------------------------------------------")
column_names_redefined = {                                                             # define new column names
'stemmingzaak_stemming_Id':'stemming_id',
'stemmingzaak_stemming_Soort':'stemming_soort',
'stemmingzaak_stemming_Fractie.Id':'fractie_id',
'stemmingzaak_stemming_Fractie.Afkorting':'party',
'stemmingzaak_stemming_Besluit.Id':'besluit_id',
'stemmingzaak_zaak_Id':'zaak_id',
'stemmingzaak_zaak_GestartOp':'day',
'document_Id':'document_id',
'document_Titel':'title',
'document_Onderwerp':'subject'}
data.rename(columns=column_names_redefined, inplace=True)                              # rename columns
data = data.drop(columns=['fractie_id','zaak_id'])                                     # drop fractie_id and zaak_id

# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
print("\n\n\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
print(f"unique: {(not data['stemming_id'].duplicated().any())}")                       # print duplicates
print(f"length: {len(data)}")                                                          # print length
print(data.iloc[0])                                                                    # print row
print((data.isna().sum()).to_frame())                                                  # print nulls
print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~


# step 2: process day
# -------------------------------------------------------------------------------------~----------------------------------------
print("\n\n\n step 2: process day")                                                    # print step
print("-----------------------------------------------------------------------")
print("- redefine day into datetime value")                                            # print substep
print("- filter on Cabinet Rutte III-IV")                                              # print substep
print("- redefine day into numeric value")                                             # print substep
data['day'] = pd.to_datetime(data['day'], utc=True)                                    # redefine day into datetime value
start = pd.Timestamp('2017-10-26', tz='CET')                                           # start of Rutte III
end = pd.Timestamp('2023-07-07', tz='CET')                                             # end of Rutte IV
data = data[(data['day'] >= start) & (data['day'] <= end)]                             # filter data
data['day'] = data['day'].apply(lambda date: (date - start).days)                      # redefine day into numeric value


# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
print("\n\n\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
print(f"unique: {(not data['stemming_id'].duplicated().any())}")                       # print duplicates
print(f"length: {len(data)}")                                                          # print length
print(data.iloc[0])                                                                    # print row
print((data.isna().sum()).to_frame())                                                  # print nulls
print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~


# step 3: process party
# -------------------------------------------------------------------------------------~----------------------------------------
print("\n\n\n step 3: process party")                                                  # print step
print("-----------------------------------------------------------------------")
print("- remove parties")                                                              # print substep
print("- rename parties")                                                              # print substep

remove = [  'Ephraim'           ,                                                      # irrelevant demerger
            'Groep Krol/vKA'    ,                                                      # discontinued party
            'Krol'              ,                                                      # discontinued party
            'Gündoğan'          ,                                                      # quit politics
            'vKA'               ]                                                      # quit politics

rename =  { 'Fractie Den Haan'  : '50PLUS' ,                                           # for analytical purposes, same name
            'Omtzigt'           : 'NSC'    ,                                           # relevant demerger into NSC
            'Groep Van Haga'    : 'BVNL'   ,                                           # relevant demerger into BVNL
            'Van Haga'          : 'BVNL'   ,                                           # relevant demerger into BVNL
            'GL'                : 'GLPvdA' ,                                           # relevant merger into GLPvdA
            'PvdA'              : 'GLPvdA'   }                                         # relevant merger into GLPvdA

data = data[~data['party'].isin(remove)]                                               # remove parties            
data['party'] = data['party'].replace(rename)                                          # rename parties


# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
print("\n\n\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
print(f"unique: {(not data['stemming_id'].duplicated().any())}")                       # print duplicates
print(f"length: {len(data)}")                                                          # print length
print(data.iloc[0])                                                                    # print row
print((data.isna().sum()).to_frame())                                                  # print nulls
print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~





# -------------------------------------------------------------------------------------~----------------------------------------
# step 4: evaluate partisanship
print("\n\n\n step 4: evaluate partisanship")                                          # print step
print("-----------------------------------------------------------------------")
count = data.groupby(['party','besluit_id'])['stemming_soort'].nunique().reset_index() # define count
unanimous = len(count[count['stemming_soort'] == 1])                                   # define count unanimous
divided = len(count[count['stemming_soort'] == 2])                                     # define count divided

plt.bar(['1 vote', '2 votes'], [unanimous, divided] , color= ['#093158','#A6700E'])    # plot barplot
plt.xlabel('Distinct count of voting types per party per motion')                      # plot x label
plt.ylabel('Frequency')                                                                # plot y label
plt.title('Partisanship')                                                              # plot title
sns.despine()                                                                          # plot despine
plt.show()                                                                             # plot show
print(f"Unanimous: {((unanimous / (unanimous + divided)) * 100)}%")                    # print percentage unanimous
print(f"Divided: {((divided / (unanimous + divided)) * 100  )}%")                      # print percentage divided


# -------------------------------------------------------------------------------------~----------------------------------------
# Step 5: group parties
print("\n\n\n step 5: group parties")                                                  # print step
print("-----------------------------------------------------------------------")
data['voor'] = (data['stemming_soort'] == 'Voor').astype(int)                          # define voor column
data['tegen'] = (data['stemming_soort'] == 'Tegen').astype(int)                        # define tegen column
exclude = ['stemming_id','stemming_soort','besluit_id','voor','tegen']                 # define excluded columns
data = data.groupby(data.columns.difference(exclude).tolist()).agg({                   # aggregate, without excluded
            'voor'        : 'sum'   ,                                                  # sum yes votes
            'tegen'       : 'sum'   ,                                                  # sum no votes
            'stemming_id' : 'first' ,                                                  # first stemming_id
            'besluit_id'  : 'first' , }).reset_index()                                 # first besluit_id
data['vote']=data.apply(lambda row: 1 if row['voor'] >= row['tegen'] else 0, axis=1)   # define stemming result, majority
data = data.drop(columns=['voor','tegen'])                                             # drop voor and tegen


# -------------------------------------------------------------------------------------~----------------------------------------
# step 6: re-evaluate partisanship
print("\n\n\n step 6: evaluate partisanship")                                          # print step
print("-----------------------------------------------------------------------")
temp = data.groupby(['party','besluit_id'])['vote'].nunique().reset_index()            # define count
unanimous = len(temp[temp['vote'] == 1])                                               # define count unanimous
divided = len(temp[temp['vote'] == 2])                                                 # define count divided

plt.bar(['1 vote', '2 votes'], [unanimous, divided], color = '#093158')                # plot barplot
plt.xlabel('Distinct count of voting types per party per motion')                      # plot x label
plt.ylabel('Frequency')                                                                # plot y label
plt.title('Partisanship')                                                              # plot title
sns.despine()                                                                          # plot despine
plt.show()                                                                             # plot show
print(f"Unanimous: {((unanimous / (unanimous + divided)) * 100)}%")                    # print percentage unanimous
print(f"Divided: {((divided / (unanimous + divided)) * 100  )}%")                      # print percentage divided


# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
print("\n\n\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
print(f"unique: {(not data['stemming_id'].duplicated().any())}")                       # print duplicates
print(f"length: {len(data)}")                                                          # print length
print(data.iloc[0])                                                                    # print row
print((data.isna().sum()).to_frame())                                                  # print nulls
print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~





# -------------------------------------------------------------------------------------~----------------------------------------
# step 7: evaluate class imbalance
print("\n\n\n step 7: evaluate class imbalance")                                       # print step
print("-----------------------------------------------------------------------")
temp = data.groupby(['party','vote'])['besluit_id'].count().unstack(fill_value=0)      # group data
col = {1: '#093158', 0: '#A6700E'}                                                     # define colors
temp.plot(kind='bar', stacked=True, color=[col.get(c, 'gray') for c in temp.columns])  # plot barplot
plt.xlabel('Party')                                                                    # plot x label
plt.ylabel('Frequency')                                                                # plot y label
plt.title('Balance')                                                                   # plot title
plt.legend(title='Vote')                                                               # plot legend
sns.despine()                                                                          # plot despine
plt.show()                                                                             # plot show


# -------------------------------------------------------------------------------------~----------------------------------------
# Step 8: display datasets
print("\n\n\n step 8: display datasets")                                                 
print("-----------------------------------------------------------------------")
structured_data = data[['stemming_id','document_id', 'party', 'day', 'vote']]          # define structured dataset
unstructured_data = data[['document_id', 'subject', 'title']]                          # define unstructured dataset
unstructured_data = unstructured_data.drop_duplicates(subset=[ 'document_id'])         # redefine into unique rows
structured_data.reset_index(drop=True, inplace=True)
unstructured_data.reset_index(drop=True, inplace=True)

print("\n retrieved dataset")                                                          # print retrieved dataset
display(data.head())                                                                   # display retrieved dataset
print(len(data))                                                                       # display retrieved dataset

print("\n structured dataset")                                                         # print structured dataset
display(structured_data.head())                                                        # display structured dataset
print(len(structured_data))                                                            # display structured dataset
file_url  = file_path + '12_data_structured_processed.csv'      
structured_data.to_csv(file_url, index=False)          

print("\n unstructured dataset")                                                       # print unstructured dataset
display(unstructured_data.head())                                                      # display unstructured dataset
print(len(unstructured_data))                                                          # display unstructured dataset
file_url  = file_path + '21_data_unstructured_base.csv'  
unstructured_data.to_csv(file_url, index=False)   

parties = [(party) for party in data['party'].unique()]                                # define list of parties
np.save('00_parties.npy', parties)                                                     # save list of parties

# -------------------------------------------------------------------------------------~----------------------------------------
print('\n---------------------------------------------------------------------------------------------------------------------')
print(f"Code duration: {round((time.time()  - dur),3)} seconds")
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# unique: True
# length: 393986
# stemmingzaak_stemming_Id                                af67af03-32cf-4790-97cb-0000341de2d1
# stemmingzaak_stemming_Soort                                                             Voor
# stemmingzaak_stemming_Fractie.Id                        a34bf6c8-834e-4dba-b4d2-f2f1b3957bd2
# stemmingzaak_stemming_Fractie.Afkorting                                               50PLUS
# stemmingzaak_stemming_Besluit.Id                        05c0994d-a89f-4494-956e-ebf5d883df1d
# stemmingzaak_zaak_Id                                    f6e2d0e1-9c77-49a9-a90e-a638b2773e19
# stemmingzaak_zaak_GestartOp                                        2017-09-12T00:00:00+02:00
# document_Id                                             165adf9a-b6d5-4085-b706-c609eea00d34
# document_Titel                                                           Vreemdelingenbeleid
# document_Onderwerp                         Motie van het lid Fritsma over het uitzetten v...
# Name: 0, dtype: object
#                                          0
# stemmingzaak_stemming_Id                 0
# stemmingzaak_stemming_Soort              0
# stemmingzaak_stemming_Fractie.Id         0
# stemmingzaak_stemming_Fractie.Afkorting  0
# stemmingzaak_stemming_Besluit.Id         0
# stemmingzaak_zaak_Id                     0
# stemmingzaak_zaak_GestartOp              0
# document_Id                              0
# document_Titel                           0
# document_Onderwerp                       0
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#  step 1: redefine column names
# -----------------------------------------------------------------------
#
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# unique: True
# length: 393986
# stemming_id                    af67af03-32cf-4790-97cb-0000341de2d1
# stemming_soort                                                 Voor
# party                                                        50PLUS
# besluit_id                     05c0994d-a89f-4494-956e-ebf5d883df1d
# day                                       2017-09-12T00:00:00+02:00
# document_id                    165adf9a-b6d5-4085-b706-c609eea00d34
# title                                           Vreemdelingenbeleid
# subject           Motie van het lid Fritsma over het uitzetten v...
# Name: 0, dtype: object
#                 0
# stemming_id     0
# stemming_soort  0
# party           0
# besluit_id      0
# day             0
# document_id     0
# title           0
# subject         0
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
#
#  step 2: process day
# -----------------------------------------------------------------------
# - redefine day into datetime value
# - filter on Cabinet Rutte III-IV
# - redefine day into numeric value
#
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# unique: True
# length: 358066
# stemming_id                    e0fe1dc7-c9c3-4b74-9625-00004cff6854
# stemming_soort                                                 Voor
# party                                                           FVD
# besluit_id                     808c1008-5cb0-41b5-aad8-ba4caa71cd99
# day                                                             448
# document_id                    0fd9cd0f-50b2-400f-a24f-9cd2646bd8d3
# title                                Maatregelen verkeersveiligheid
# subject           Motie van het lid Remco Dijkstra over maatrege...
# Name: 1, dtype: object
#                 0
# stemming_id     0
# stemming_soort  0
# party           0
# besluit_id      0
# day             0
# document_id     0
# title           0
# subject         0
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
#
#  step 3: process party
# -----------------------------------------------------------------------
# - remove parties
# - rename parties
#
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# unique: True
# length: 345650
# stemming_id                    e0fe1dc7-c9c3-4b74-9625-00004cff6854
# stemming_soort                                                 Voor
# party                                                           FVD
# besluit_id                     808c1008-5cb0-41b5-aad8-ba4caa71cd99
# day                                                             448
# document_id                    0fd9cd0f-50b2-400f-a24f-9cd2646bd8d3
# title                                Maatregelen verkeersveiligheid
# subject           Motie van het lid Remco Dijkstra over maatrege...
# Name: 1, dtype: object
#                 0
# stemming_id     0
# stemming_soort  0
# party           0
# besluit_id      0
# day             0
# document_id     0
# title           0
# subject         0
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
#
#  step 4: evaluate partisanship
# -----------------------------------------------------------------------
# Unanimous: 99.65588164183208%
# Divided: 0.3441183581679258%
#
#
#
#  step 5: group parties
# -----------------------------------------------------------------------
#
#
#
#  step 6: evaluate partisanship
# -----------------------------------------------------------------------
# Unanimous: 100.0%
# Divided: 0.0%
#
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# unique: True
# length: 301854
# day                                                            7
# document_id                 08f70318-bcee-4284-95d8-25539822718c
# party                                                     50PLUS
# subject        Motie van de leden Van der Staaij en Roemer ov...
# title               Nota over de toestand van ’s Rijks Financiën
# stemming_id                 de29f06b-cab4-416b-82a1-cddc3a610551
# besluit_id                  78dee20f-5f17-4697-9e40-201dc0c3f88f
# vote                                                           1
# Name: 0, dtype: object
#              0
# day          0
# document_id  0
# party        0
# subject      0
# title        0
# stemming_id  0
# besluit_id   0
# vote         0
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
#
#  step 7: evaluate class imbalance
# -----------------------------------------------------------------------
#  step 8: display datasets
# -----------------------------------------------------------------------
#
#  retrieved dataset
#    day                           document_id   party  \
# 0    7  08f70318-bcee-4284-95d8-25539822718c  50PLUS
# 1    7  08f70318-bcee-4284-95d8-25539822718c     CDA
# 2    7  08f70318-bcee-4284-95d8-25539822718c      CU
# 3    7  08f70318-bcee-4284-95d8-25539822718c     D66
# 4    7  08f70318-bcee-4284-95d8-25539822718c    DENK
#
#                                              subject  \
# 0  Motie van de leden Van der Staaij en Roemer ov...
# 1  Motie van de leden Van der Staaij en Roemer ov...
# 2  Motie van de leden Van der Staaij en Roemer ov...
# 3  Motie van de leden Van der Staaij en Roemer ov...
# 4  Motie van de leden Van der Staaij en Roemer ov...
#
#                                           title  \
# 0  Nota over de toestand van ’s Rijks Financiën
# 1  Nota over de toestand van ’s Rijks Financiën
# 2  Nota over de toestand van ’s Rijks Financiën
# 3  Nota over de toestand van ’s Rijks Financiën
# 4  Nota over de toestand van ’s Rijks Financiën
#
#                             stemming_id                            besluit_id  \
# 0  de29f06b-cab4-416b-82a1-cddc3a610551  78dee20f-5f17-4697-9e40-201dc0c3f88f
# 1  b317ab13-1ece-4434-8edd-bc361f18f640  78dee20f-5f17-4697-9e40-201dc0c3f88f
# 2  91ffed0f-de9c-4d25-b448-61f47490a4a4  78dee20f-5f17-4697-9e40-201dc0c3f88f
# 3  6f9227ef-0b27-406d-836d-fd9c5bf548b3  78dee20f-5f17-4697-9e40-201dc0c3f88f
# 4  8b3b9edd-dc39-46db-9236-2b490eeb9188  78dee20f-5f17-4697-9e40-201dc0c3f88f
#
#    vote
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1
# 301854
#
#  structured dataset
#                             stemming_id                           document_id  \
# 0  de29f06b-cab4-416b-82a1-cddc3a610551  08f70318-bcee-4284-95d8-25539822718c
# 1  b317ab13-1ece-4434-8edd-bc361f18f640  08f70318-bcee-4284-95d8-25539822718c
# 2  91ffed0f-de9c-4d25-b448-61f47490a4a4  08f70318-bcee-4284-95d8-25539822718c
# 3  6f9227ef-0b27-406d-836d-fd9c5bf548b3  08f70318-bcee-4284-95d8-25539822718c
# 4  8b3b9edd-dc39-46db-9236-2b490eeb9188  08f70318-bcee-4284-95d8-25539822718c
#
#     party  day  vote
# 0  50PLUS    7     1
# 1     CDA    7     1
# 2      CU    7     1
# 3     D66    7     1
# 4    DENK    7     1
# 301854
#
#  unstructured dataset
#                             document_id  \
# 0  08f70318-bcee-4284-95d8-25539822718c
# 1  17e137d1-978d-4733-85c6-d0471ea12877
# 2  24c42b57-a9d0-4352-b495-9bc092cbcbc0
# 3  360afadc-3439-4bd6-99a0-c8eb3619a15c
# 4  3692e3b0-ad24-44d7-b225-5a31dbbd4233
#
#                                              subject  \
# 0  Motie van de leden Van der Staaij en Roemer ov...
# 1  Motie van het lid Roemer c.s. . over nader ond...
# 2  Motie van het lid Thieme over geen prioriteit ...
# 3  Motie van de leden Van der Staaij en Wilders o...
# 4  Gewijzigde motie van het lid Asscher c.s. (t.v...
#
#                                           title
# 0  Nota over de toestand van ’s Rijks Financiën
# 1  Nota over de toestand van ’s Rijks Financiën
# 2  Nota over de toestand van ’s Rijks Financiën
# 3  Nota over de toestand van ’s Rijks Financiën
# 4  Nota over de toestand van ’s Rijks Financiën
# 20666
#
# ---------------------------------------------------------------------------------------------------------------------
# Code duration: 20.238 seconds
